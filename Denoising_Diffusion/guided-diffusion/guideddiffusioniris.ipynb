# %%
# !nvidia-smi
# Out:
# Wed Jun 21 18:17:48 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip freeze

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !echo 'y' | sudo apt install mpich
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# mpich is already the newest version (3.3.2-2build1).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %%
# !which mpiexec
# Out:
# /usr/bin/mpiexec

# %%
# !pip install blobfile==1.3.4
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install tqdm
# !pip install mpi4py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu118, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install -e /content/gdrive/MyDrive/guided-diffusion
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gdrive/MyDrive/guided-diffusion
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: guided-diffusion
#     Found existing installation: guided-diffusion 0.0.0
#     Uninstalling guided-diffusion-0.0.0:
#       Successfully uninstalled guided-diffusion-0.0.0
#   Running setup.py develop for guided-diffusion
# ...

# %%
# !pip install git+https://github.com/openai/guided-diffusion.git

# %%
# !pip freeze

# %%
# %env OPENAI_LOGDIR=/content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/logs
# Out:
# env: OPENAI_LOGDIR=/content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/logs

# %%
import guided_diffusion

# %%
# !echo $OPENAI_LOGDIR
# Out:
# /content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/logs

# %%
! python /content/gdrive/MyDrive/guided-diffusion/scripts/image_train.py --data_dir /content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/ --image_size 64 --num_channels 128 --num_res_blocks 3 --diffusion_steps 4000 --noise_schedule linear --lr 1e-4 --batch_size 32 --lr_anneal_steps 2001 --save_interval 500
# Out:
# Logging to /content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/logs
# creating model and diffusion...
# creating data loader...
# training...
# -------------------------
# | grad_norm  | 3.11     |
# | loss       | 1        |
# | loss_q0    | 1.01     |
# | loss_q1    | 1        |
# | loss_q2    | 0.997    |
# | loss_q3    | 0.997    |
# | mse        | 1        |
# | mse_q0     | 1.01     |
# | mse_q1     | 1        |
# | mse_q2     | 0.997    |
# | mse_q3     | 0.997    |
# | param_norm | 227      |
# | samples    | 32       |
# | step       | 0        |
# -------------------------
# saving model 0...
# saving model 0.9999...
# -------------------------
# | grad_norm  | 3.29     |
# | loss       | 0.902    |
# | loss_q0    | 0.929    |
# | loss_q1    | 0.897    |
# | loss_q2    | 0.893    |
# | loss_q3    | 0.894    |
# | mse        | 0.902    |
# | mse_q0     | 0.929    |
# | mse_q1     | 0.897    |
# | mse_q2     | 0.893    |
# | mse_q3     | 0.894    |
# ...

# %%
# %env OPENAI_LOGDIR=/content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/sample_logs
# Out:
# env: OPENAI_LOGDIR=/content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/sample_logs

# %%
# !python /content/gdrive/MyDrive/guided-diffusion/scripts/image_sample.py --model_path /content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/logs/model002000.pt --image_size 64 --num_channels 128 --num_res_blocks 3 --diffusion_steps 4000 --noise_schedule linear --batch_size 1 --num_samples 100 --timestep_respacing 250
# Out:
# Logging to /content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/sample_logs
# creating model and diffusion...
# sampling...
# created 1 samples
# created 2 samples
# created 3 samples
# created 4 samples
# created 5 samples
# created 6 samples
# created 7 samples
# created 8 samples
# created 9 samples
# created 10 samples
# created 11 samples
# created 12 samples
# created 13 samples
# created 14 samples
# created 15 samples
# created 16 samples
# created 17 samples
# created 18 samples
# created 19 samples
# created 20 samples
# created 21 samples
# created 22 samples
# created 23 samples
# created 24 samples
# created 25 samples
# created 26 samples
# created 27 samples
# created 28 samples
# created 29 samples
# created 30 samples
# created 31 samples
# created 32 samples
# created 33 samples
# created 34 samples
# created 35 samples
# created 36 samples
# created 37 samples
# created 38 samples
# created 39 samples
# created 40 samples
# created 41 samples
# ...

# %%
import numpy as np
import cv2

# %%
sample_arr=np.load('/content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/sample_logs/samples_100x64x64x3.npz')
sample_arr=sample_arr["arr_0"]
c=0
for i in sample_arr:
  cv2.imwrite("/content/gdrive/MyDrive/guided-diffusion/datasets/IITD_LQ_64/sample_logs/sample"+str(c)+".png", i)
  c+=1
