# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/iit-delhi/L/1661.bmp
# /kaggle/input/iit-delhi/L/665.bmp
# /kaggle/input/iit-delhi/L/1212.bmp
# /kaggle/input/iit-delhi/L/2145.bmp
# /kaggle/input/iit-delhi/L/421.bmp
# /kaggle/input/iit-delhi/L/1672.bmp
# /kaggle/input/iit-delhi/L/129.bmp
# /kaggle/input/iit-delhi/L/184.bmp
# /kaggle/input/iit-delhi/L/1764.bmp
# /kaggle/input/iit-delhi/L/2012.bmp
# /kaggle/input/iit-delhi/L/2131.bmp
# /kaggle/input/iit-delhi/L/65.bmp
# /kaggle/input/iit-delhi/L/904.bmp
# /kaggle/input/iit-delhi/L/1532.bmp
# /kaggle/input/iit-delhi/L/962.bmp
# /kaggle/input/iit-delhi/L/1163.bmp
# /kaggle/input/iit-delhi/L/1803.bmp
# /kaggle/input/iit-delhi/L/1405.bmp
# /kaggle/input/iit-delhi/L/1713.bmp
# /kaggle/input/iit-delhi/L/2202.bmp
# /kaggle/input/iit-delhi/L/1221.bmp
# /kaggle/input/iit-delhi/L/1352.bmp
# /kaggle/input/iit-delhi/L/243.bmp
# /kaggle/input/iit-delhi/L/562.bmp
# /kaggle/input/iit-delhi/L/623.bmp
# /kaggle/input/iit-delhi/L/632.bmp
# /kaggle/input/iit-delhi/L/312.bmp
# /kaggle/input/iit-delhi/L/1501.bmp
# /kaggle/input/iit-delhi/L/2203.bmp
# /kaggle/input/iit-delhi/L/475.bmp
# /kaggle/input/iit-delhi/L/2193.bmp
# /kaggle/input/iit-delhi/L/502.bmp
# /kaggle/input/iit-delhi/L/1534.bmp
# /kaggle/input/iit-delhi/L/133.bmp
# /kaggle/input/iit-delhi/L/1315.bmp
# /kaggle/input/iit-delhi/L/97.bmp
# /kaggle/input/iit-delhi/L/232.bmp
# /kaggle/input/iit-delhi/L/603.bmp
# /kaggle/input/iit-delhi/L/1071.bmp
# /kaggle/input/iit-delhi/L/1752.bmp
# /kaggle/input/iit-delhi/L/703.bmp
# /kaggle/input/iit-delhi/L/374.bmp
# /kaggle/input/iit-delhi/L/733.bmp
# /kaggle/input/iit-delhi/L/831.bmp
# /kaggle/input/iit-delhi/L/1673.bmp
# /kaggle/input/iit-delhi/L/1762.bmp
# /kaggle/input/iit-delhi/L/554.bmp
# /kaggle/input/iit-delhi/L/671.bmp
# /kaggle/input/iit-delhi/L/1773.bmp
# /kaggle/input/iit-delhi/L/1622.bmp
# /kaggle/input/iit-delhi/L/942.bmp
# /kaggle/input/iit-delhi/L/16.bmp
# /kaggle/input/iit-delhi/L/132.bmp
# /kaggle/input/iit-delhi/L/119.bmp
# /kaggle/input/iit-delhi/L/551.bmp
# /kaggle/input/iit-delhi/L/4.bmp
# /kaggle/input/iit-delhi/L/1493.bmp
# /kaggle/input/iit-delhi/L/971.bmp
# /kaggle/input/iit-delhi/L/645.bmp
# /kaggle/input/iit-delhi/L/2104.bmp
# /kaggle/input/iit-delhi/L/1883.bmp
# /kaggle/input/iit-delhi/L/961.bmp
# /kaggle/input/iit-delhi/L/211.bmp
# /kaggle/input/iit-delhi/L/1453.bmp
# /kaggle/input/iit-delhi/L/1144.bmp
# /kaggle/input/iit-delhi/L/1821.bmp
# /kaggle/input/iit-delhi/L/1805.bmp
# /kaggle/input/iit-delhi/L/2031.bmp
# /kaggle/input/iit-delhi/L/872.bmp
# /kaggle/input/iit-delhi/L/1374.bmp
# /kaggle/input/iit-delhi/L/172.bmp
# /kaggle/input/iit-delhi/L/2013.bmp
# /kaggle/input/iit-delhi/L/1765.bmp
# /kaggle/input/iit-delhi/L/973.bmp
# /kaggle/input/iit-delhi/L/1712.bmp
# /kaggle/input/iit-delhi/L/1222.bmp
# /kaggle/input/iit-delhi/L/1741.bmp
# /kaggle/input/iit-delhi/L/553.bmp
# /kaggle/input/iit-delhi/L/254.bmp
# /kaggle/input/iit-delhi/L/155.bmp
# /kaggle/input/iit-delhi/L/1443.bmp
# /kaggle/input/iit-delhi/L/1915.bmp
# /kaggle/input/iit-delhi/L/93.bmp
# /kaggle/input/iit-delhi/L/1031.bmp
# /kaggle/input/iit-delhi/L/791.bmp
# /kaggle/input/iit-delhi/L/322.bmp
# /kaggle/input/iit-delhi/L/1034.bmp
# /kaggle/input/iit-delhi/L/325.bmp
# /kaggle/input/iit-delhi/L/402.bmp
# /kaggle/input/iit-delhi/L/1933.bmp
# /kaggle/input/iit-delhi/L/96.bmp
# /kaggle/input/iit-delhi/L/443.bmp
# /kaggle/input/iit-delhi/L/39.bmp
# /kaggle/input/iit-delhi/L/695.bmp
# /kaggle/input/iit-delhi/L/1263.bmp
# /kaggle/input/iit-delhi/L/213.bmp
# /kaggle/input/iit-delhi/L/1162.bmp
# /kaggle/input/iit-delhi/L/383.bmp
# /kaggle/input/iit-delhi/L/90.bmp
# /kaggle/input/iit-delhi/L/542.bmp
# /kaggle/input/iit-delhi/L/111.bmp
# /kaggle/input/iit-delhi/L/853.bmp
# /kaggle/input/iit-delhi/L/1225.bmp
# /kaggle/input/iit-delhi/L/1353.bmp
# /kaggle/input/iit-delhi/L/1214.bmp
# /kaggle/input/iit-delhi/L/1321.bmp
# /kaggle/input/iit-delhi/L/2155.bmp
# /kaggle/input/iit-delhi/L/131.bmp
# /kaggle/input/iit-delhi/L/435.bmp
# /kaggle/input/iit-delhi/L/455.bmp
# /kaggle/input/iit-delhi/L/251.bmp
# /kaggle/input/iit-delhi/L/1151.bmp
# /kaggle/input/iit-delhi/L/1784.bmp
# /kaggle/input/iit-delhi/L/763.bmp
# /kaggle/input/iit-delhi/L/1924.bmp
# /kaggle/input/iit-delhi/L/1652.bmp
# /kaggle/input/iit-delhi/L/1495.bmp
# /kaggle/input/iit-delhi/L/913.bmp
# /kaggle/input/iit-delhi/L/804.bmp
# /kaggle/input/iit-delhi/L/2215.bmp
# /kaggle/input/iit-delhi/L/1541.bmp
# /kaggle/input/iit-delhi/L/585.bmp
# /kaggle/input/iit-delhi/L/1603.bmp
# /kaggle/input/iit-delhi/L/646.bmp
# /kaggle/input/iit-delhi/L/1402.bmp
# /kaggle/input/iit-delhi/L/823.bmp
# /kaggle/input/iit-delhi/L/693.bmp
# /kaggle/input/iit-delhi/L/782.bmp
# /kaggle/input/iit-delhi/L/1811.bmp
# /kaggle/input/iit-delhi/L/1371.bmp
# /kaggle/input/iit-delhi/L/1184.bmp
# /kaggle/input/iit-delhi/L/1282.bmp
# /kaggle/input/iit-delhi/L/151.bmp
# /kaggle/input/iit-delhi/L/128.bmp
# /kaggle/input/iit-delhi/L/1462.bmp
# /kaggle/input/iit-delhi/L/503.bmp
# /kaggle/input/iit-delhi/L/1053.bmp
# /kaggle/input/iit-delhi/L/1333.bmp
# /kaggle/input/iit-delhi/L/95.bmp
# /kaggle/input/iit-delhi/L/532.bmp
# /kaggle/input/iit-delhi/L/1475.bmp
# /kaggle/input/iit-delhi/L/1123.bmp
# /kaggle/input/iit-delhi/L/1612.bmp
# /kaggle/input/iit-delhi/L/1664.bmp
# /kaggle/input/iit-delhi/L/375.bmp
# /kaggle/input/iit-delhi/L/2011.bmp
# /kaggle/input/iit-delhi/L/1552.bmp
# /kaggle/input/iit-delhi/L/1781.bmp
# /kaggle/input/iit-delhi/L/125.bmp
# /kaggle/input/iit-delhi/L/452.bmp
# /kaggle/input/iit-delhi/L/1152.bmp
# /kaggle/input/iit-delhi/L/2113.bmp
# /kaggle/input/iit-delhi/L/1792.bmp
# /kaggle/input/iit-delhi/L/202.bmp
# /kaggle/input/iit-delhi/L/235.bmp
# /kaggle/input/iit-delhi/L/612.bmp
# /kaggle/input/iit-delhi/L/1925.bmp
# /kaggle/input/iit-delhi/L/1424.bmp
# /kaggle/input/iit-delhi/L/58.bmp
# /kaggle/input/iit-delhi/L/353.bmp
# /kaggle/input/iit-delhi/L/1301.bmp
# /kaggle/input/iit-delhi/L/941.bmp
# /kaggle/input/iit-delhi/L/1324.bmp
# /kaggle/input/iit-delhi/L/1021.bmp
# /kaggle/input/iit-delhi/L/1825.bmp
# /kaggle/input/iit-delhi/L/1671.bmp
# /kaggle/input/iit-delhi/L/2045.bmp
# /kaggle/input/iit-delhi/L/1631.bmp
# /kaggle/input/iit-delhi/L/1232.bmp
# /kaggle/input/iit-delhi/L/601.bmp
# /kaggle/input/iit-delhi/L/625.bmp
# /kaggle/input/iit-delhi/L/23.bmp
# /kaggle/input/iit-delhi/L/1135.bmp
# /kaggle/input/iit-delhi/L/1802.bmp
# /kaggle/input/iit-delhi/L/323.bmp
# /kaggle/input/iit-delhi/L/724.bmp
# /kaggle/input/iit-delhi/L/271.bmp
# /kaggle/input/iit-delhi/L/2061.bmp
# /kaggle/input/iit-delhi/L/735.bmp
# /kaggle/input/iit-delhi/L/1701.bmp
# /kaggle/input/iit-delhi/L/462.bmp
# /kaggle/input/iit-delhi/L/401.bmp
# /kaggle/input/iit-delhi/L/1412.bmp
# /kaggle/input/iit-delhi/L/42.bmp
# /kaggle/input/iit-delhi/L/514.bmp
# /kaggle/input/iit-delhi/L/582.bmp
# /kaggle/input/iit-delhi/L/241.bmp
# /kaggle/input/iit-delhi/L/334.bmp
# /kaggle/input/iit-delhi/L/341.bmp
# /kaggle/input/iit-delhi/L/1692.bmp
# /kaggle/input/iit-delhi/L/672.bmp
# /kaggle/input/iit-delhi/L/1293.bmp
# /kaggle/input/iit-delhi/L/1383.bmp
# /kaggle/input/iit-delhi/L/1485.bmp
# /kaggle/input/iit-delhi/L/99.bmp
# /kaggle/input/iit-delhi/L/1283.bmp
# /kaggle/input/iit-delhi/L/1494.bmp
# /kaggle/input/iit-delhi/L/765.bmp
# /kaggle/input/iit-delhi/L/1354.bmp
# /kaggle/input/iit-delhi/L/922.bmp
# /kaggle/input/iit-delhi/L/491.bmp
# /kaggle/input/iit-delhi/L/1523.bmp
# /kaggle/input/iit-delhi/L/1242.bmp
# /kaggle/input/iit-delhi/L/1341.bmp
# /kaggle/input/iit-delhi/L/731.bmp
# /kaggle/input/iit-delhi/L/1302.bmp
# /kaggle/input/iit-delhi/L/1581.bmp
# /kaggle/input/iit-delhi/L/283.bmp
# /kaggle/input/iit-delhi/L/1192.bmp
# /kaggle/input/iit-delhi/L/1164.bmp
# /kaggle/input/iit-delhi/L/852.bmp
# /kaggle/input/iit-delhi/L/12.bmp
# /kaggle/input/iit-delhi/L/372.bmp
# /kaggle/input/iit-delhi/L/713.bmp
# /kaggle/input/iit-delhi/L/815.bmp
# /kaggle/input/iit-delhi/L/1644.bmp
# /kaggle/input/iit-delhi/L/47.bmp
# /kaggle/input/iit-delhi/L/805.bmp
# /kaggle/input/iit-delhi/L/1441.bmp
# /kaggle/input/iit-delhi/L/881.bmp
# /kaggle/input/iit-delhi/L/1735.bmp
# /kaggle/input/iit-delhi/L/2023.bmp
# /kaggle/input/iit-delhi/L/1965.bmp
# /kaggle/input/iit-delhi/L/772.bmp
# /kaggle/input/iit-delhi/L/1004.bmp
# /kaggle/input/iit-delhi/L/1791.bmp
# /kaggle/input/iit-delhi/L/674.bmp
# /kaggle/input/iit-delhi/L/1011.bmp
# /kaggle/input/iit-delhi/L/311.bmp
# /kaggle/input/iit-delhi/L/781.bmp
# /kaggle/input/iit-delhi/L/802.bmp
# /kaggle/input/iit-delhi/L/534.bmp
# /kaggle/input/iit-delhi/L/144.bmp
# /kaggle/input/iit-delhi/L/1015.bmp
# /kaggle/input/iit-delhi/L/1564.bmp
# /kaggle/input/iit-delhi/L/441.bmp
# /kaggle/input/iit-delhi/L/1393.bmp
# /kaggle/input/iit-delhi/L/1351.bmp
# /kaggle/input/iit-delhi/L/891.bmp
# /kaggle/input/iit-delhi/L/783.bmp
# /kaggle/input/iit-delhi/L/87.bmp
# /kaggle/input/iit-delhi/L/1993.bmp
# /kaggle/input/iit-delhi/L/1005.bmp
# /kaggle/input/iit-delhi/L/1893.bmp
# /kaggle/input/iit-delhi/L/1694.bmp
# /kaggle/input/iit-delhi/L/692.bmp
# /kaggle/input/iit-delhi/L/1112.bmp
# /kaggle/input/iit-delhi/L/332.bmp
# /kaggle/input/iit-delhi/L/365.bmp
# /kaggle/input/iit-delhi/L/143.bmp
# /kaggle/input/iit-delhi/L/1865.bmp
# /kaggle/input/iit-delhi/L/521.bmp
# /kaggle/input/iit-delhi/L/574.bmp
# /kaggle/input/iit-delhi/L/1254.bmp
# /kaggle/input/iit-delhi/L/1431.bmp
# /kaggle/input/iit-delhi/L/1975.bmp
# /kaggle/input/iit-delhi/L/984.bmp
# /kaggle/input/iit-delhi/L/214.bmp
# /kaggle/input/iit-delhi/L/784.bmp
# /kaggle/input/iit-delhi/L/134.bmp
# /kaggle/input/iit-delhi/L/1325.bmp
# /kaggle/input/iit-delhi/L/37.bmp
# /kaggle/input/iit-delhi/L/1684.bmp
# /kaggle/input/iit-delhi/L/1613.bmp
# /kaggle/input/iit-delhi/L/1193.bmp
# /kaggle/input/iit-delhi/L/1413.bmp
# /kaggle/input/iit-delhi/L/114.bmp
# /kaggle/input/iit-delhi/L/28.bmp
# /kaggle/input/iit-delhi/L/2092.bmp
# /kaggle/input/iit-delhi/L/1785.bmp
# /kaggle/input/iit-delhi/L/1955.bmp
# /kaggle/input/iit-delhi/L/572.bmp
# /kaggle/input/iit-delhi/L/545.bmp
# /kaggle/input/iit-delhi/L/1245.bmp
# /kaggle/input/iit-delhi/L/923.bmp
# /kaggle/input/iit-delhi/L/1674.bmp
# /kaggle/input/iit-delhi/L/107.bmp
# /kaggle/input/iit-delhi/L/1572.bmp
# /kaggle/input/iit-delhi/L/1512.bmp
# /kaggle/input/iit-delhi/L/1141.bmp
# /kaggle/input/iit-delhi/L/1382.bmp
# /kaggle/input/iit-delhi/L/1954.bmp
# /kaggle/input/iit-delhi/L/1.bmp
# /kaggle/input/iit-delhi/L/2231.bmp
# /kaggle/input/iit-delhi/L/59.bmp
# /kaggle/input/iit-delhi/L/101.bmp
# /kaggle/input/iit-delhi/L/2063.bmp
# /kaggle/input/iit-delhi/L/1384.bmp
# /kaggle/input/iit-delhi/L/932.bmp
# /kaggle/input/iit-delhi/L/2201.bmp
# /kaggle/input/iit-delhi/L/1171.bmp
# /kaggle/input/iit-delhi/L/721.bmp
# /kaggle/input/iit-delhi/L/995.bmp
# /kaggle/input/iit-delhi/L/1234.bmp
# /kaggle/input/iit-delhi/L/684.bmp
# /kaggle/input/iit-delhi/L/1813.bmp
# /kaggle/input/iit-delhi/L/1484.bmp
# /kaggle/input/iit-delhi/L/221.bmp
# /kaggle/input/iit-delhi/L/1722.bmp
# /kaggle/input/iit-delhi/L/631.bmp
# /kaggle/input/iit-delhi/L/712.bmp
# /kaggle/input/iit-delhi/L/533.bmp
# /kaggle/input/iit-delhi/L/515.bmp
# /kaggle/input/iit-delhi/L/1913.bmp
# /kaggle/input/iit-delhi/L/29.bmp
# /kaggle/input/iit-delhi/L/2171.bmp
# /kaggle/input/iit-delhi/L/305.bmp
# /kaggle/input/iit-delhi/L/2234.bmp
# /kaggle/input/iit-delhi/L/704.bmp
# /kaggle/input/iit-delhi/L/1931.bmp
# /kaggle/input/iit-delhi/L/701.bmp
# /kaggle/input/iit-delhi/L/1345.bmp
# /kaggle/input/iit-delhi/L/752.bmp
# /kaggle/input/iit-delhi/L/1882.bmp
# /kaggle/input/iit-delhi/L/1385.bmp
# /kaggle/input/iit-delhi/L/774.bmp
# /kaggle/input/iit-delhi/L/725.bmp
# /kaggle/input/iit-delhi/L/444.bmp
# /kaggle/input/iit-delhi/L/1995.bmp
# /kaggle/input/iit-delhi/L/843.bmp
# /kaggle/input/iit-delhi/L/1295.bmp
# /kaggle/input/iit-delhi/L/215.bmp
# /kaggle/input/iit-delhi/L/1625.bmp
# /kaggle/input/iit-delhi/L/2221.bmp
# /kaggle/input/iit-delhi/L/255.bmp
# /kaggle/input/iit-delhi/L/685.bmp
# /kaggle/input/iit-delhi/L/413.bmp
# /kaggle/input/iit-delhi/L/2103.bmp
# /kaggle/input/iit-delhi/L/1432.bmp
# /kaggle/input/iit-delhi/L/2084.bmp
# /kaggle/input/iit-delhi/L/86.bmp
# /kaggle/input/iit-delhi/L/1364.bmp
# /kaggle/input/iit-delhi/L/1703.bmp
# /kaggle/input/iit-delhi/L/18.bmp
# /kaggle/input/iit-delhi/L/291.bmp
# /kaggle/input/iit-delhi/L/652.bmp
# /kaggle/input/iit-delhi/L/1783.bmp
# /kaggle/input/iit-delhi/L/2091.bmp
# /kaggle/input/iit-delhi/L/321.bmp
# /kaggle/input/iit-delhi/L/1483.bmp
# /kaggle/input/iit-delhi/L/242.bmp
# /kaggle/input/iit-delhi/L/75.bmp
# /kaggle/input/iit-delhi/L/934.bmp
# /kaggle/input/iit-delhi/L/1914.bmp
# /kaggle/input/iit-delhi/L/2035.bmp
# /kaggle/input/iit-delhi/L/494.bmp
# /kaggle/input/iit-delhi/L/832.bmp
# /kaggle/input/iit-delhi/L/593.bmp
# /kaggle/input/iit-delhi/L/266.bmp
# /kaggle/input/iit-delhi/L/2204.bmp
# /kaggle/input/iit-delhi/L/495.bmp
# /kaggle/input/iit-delhi/L/381.bmp
# /kaggle/input/iit-delhi/L/424.bmp
# /kaggle/input/iit-delhi/L/2081.bmp
# /kaggle/input/iit-delhi/L/1984.bmp
# /kaggle/input/iit-delhi/L/512.bmp
# /kaggle/input/iit-delhi/L/83.bmp
# /kaggle/input/iit-delhi/L/1064.bmp
# /kaggle/input/iit-delhi/L/822.bmp
# /kaggle/input/iit-delhi/L/108.bmp
# /kaggle/input/iit-delhi/L/72.bmp
# /kaggle/input/iit-delhi/L/884.bmp
# /kaggle/input/iit-delhi/L/362.bmp
# /kaggle/input/iit-delhi/L/2.bmp
# /kaggle/input/iit-delhi/L/1912.bmp
# /kaggle/input/iit-delhi/L/633.bmp
# /kaggle/input/iit-delhi/L/1401.bmp
# /kaggle/input/iit-delhi/L/2222.bmp
# /kaggle/input/iit-delhi/L/6.bmp
# /kaggle/input/iit-delhi/L/304.bmp
# /kaggle/input/iit-delhi/L/2114.bmp
# /kaggle/input/iit-delhi/L/974.bmp
# /kaggle/input/iit-delhi/L/2041.bmp
# /kaggle/input/iit-delhi/L/964.bmp
# /kaggle/input/iit-delhi/L/363.bmp
# /kaggle/input/iit-delhi/L/2015.bmp
# /kaggle/input/iit-delhi/L/1942.bmp
# /kaggle/input/iit-delhi/L/564.bmp
# /kaggle/input/iit-delhi/L/955.bmp
# /kaggle/input/iit-delhi/L/84.bmp
# /kaggle/input/iit-delhi/L/1104.bmp
# /kaggle/input/iit-delhi/L/865.bmp
# /kaggle/input/iit-delhi/L/2022.bmp
# /kaggle/input/iit-delhi/L/1861.bmp
# /kaggle/input/iit-delhi/L/1624.bmp
# /kaggle/input/iit-delhi/L/1474.bmp
# /kaggle/input/iit-delhi/L/1044.bmp
# /kaggle/input/iit-delhi/L/2004.bmp
# /kaggle/input/iit-delhi/L/85.bmp
# /kaggle/input/iit-delhi/L/1754.bmp
# /kaggle/input/iit-delhi/L/1804.bmp
# /kaggle/input/iit-delhi/L/1833.bmp
# /kaggle/input/iit-delhi/L/915.bmp
# /kaggle/input/iit-delhi/L/1251.bmp
# /kaggle/input/iit-delhi/L/1032.bmp
# /kaggle/input/iit-delhi/L/60.bmp
# /kaggle/input/iit-delhi/L/1012.bmp
# /kaggle/input/iit-delhi/L/1002.bmp
# /kaggle/input/iit-delhi/L/855.bmp
# /kaggle/input/iit-delhi/L/1473.bmp
# /kaggle/input/iit-delhi/L/1205.bmp
# /kaggle/input/iit-delhi/L/1303.bmp
# /kaggle/input/iit-delhi/L/1133.bmp
# /kaggle/input/iit-delhi/L/1525.bmp
# /kaggle/input/iit-delhi/L/742.bmp
# /kaggle/input/iit-delhi/L/764.bmp
# /kaggle/input/iit-delhi/L/285.bmp
# /kaggle/input/iit-delhi/L/1175.bmp
# /kaggle/input/iit-delhi/L/1194.bmp
# /kaggle/input/iit-delhi/L/14.bmp
# /kaggle/input/iit-delhi/L/663.bmp
# /kaggle/input/iit-delhi/L/2082.bmp
# /kaggle/input/iit-delhi/L/893.bmp
# /kaggle/input/iit-delhi/L/62.bmp
# /kaggle/input/iit-delhi/L/463.bmp
# /kaggle/input/iit-delhi/L/201.bmp
# /kaggle/input/iit-delhi/L/682.bmp
# /kaggle/input/iit-delhi/L/1743.bmp
# /kaggle/input/iit-delhi/L/651.bmp
# /kaggle/input/iit-delhi/L/1273.bmp
# /kaggle/input/iit-delhi/L/1513.bmp
# /kaggle/input/iit-delhi/L/2214.bmp
# /kaggle/input/iit-delhi/L/1452.bmp
# /kaggle/input/iit-delhi/L/1705.bmp
# /kaggle/input/iit-delhi/L/1654.bmp
# /kaggle/input/iit-delhi/L/2024.bmp
# /kaggle/input/iit-delhi/L/513.bmp
# /kaggle/input/iit-delhi/L/171.bmp
# /kaggle/input/iit-delhi/L/162.bmp
# /kaggle/input/iit-delhi/L/112.bmp
# /kaggle/input/iit-delhi/L/1262.bmp
# /kaggle/input/iit-delhi/L/74.bmp
# /kaggle/input/iit-delhi/L/691.bmp
# /kaggle/input/iit-delhi/L/1063.bmp
# /kaggle/input/iit-delhi/L/1573.bmp
# /kaggle/input/iit-delhi/L/1085.bmp
# /kaggle/input/iit-delhi/L/1521.bmp
# /kaggle/input/iit-delhi/L/1464.bmp
# /kaggle/input/iit-delhi/L/861.bmp
# /kaggle/input/iit-delhi/L/1885.bmp
# /kaggle/input/iit-delhi/L/100.bmp
# /kaggle/input/iit-delhi/L/1974.bmp
# /kaggle/input/iit-delhi/L/1653.bmp
# /kaggle/input/iit-delhi/L/483.bmp
# /kaggle/input/iit-delhi/L/1543.bmp
# /kaggle/input/iit-delhi/L/1994.bmp
# /kaggle/input/iit-delhi/L/892.bmp
# /kaggle/input/iit-delhi/L/102.bmp
# /kaggle/input/iit-delhi/L/395.bmp
# /kaggle/input/iit-delhi/L/324.bmp
# /kaggle/input/iit-delhi/L/1423.bmp
# /kaggle/input/iit-delhi/L/45.bmp
# /kaggle/input/iit-delhi/L/2224.bmp
# /kaggle/input/iit-delhi/L/811.bmp
# /kaggle/input/iit-delhi/L/115.bmp
# /kaggle/input/iit-delhi/L/2062.bmp
# /kaggle/input/iit-delhi/L/1202.bmp
# /kaggle/input/iit-delhi/L/1421.bmp
# /kaggle/input/iit-delhi/L/655.bmp
# /kaggle/input/iit-delhi/L/485.bmp
# /kaggle/input/iit-delhi/L/944.bmp
# /kaggle/input/iit-delhi/L/40.bmp
# /kaggle/input/iit-delhi/L/1595.bmp
# /kaggle/input/iit-delhi/L/2143.bmp
# /kaggle/input/iit-delhi/L/2174.bmp
# /kaggle/input/iit-delhi/L/1361.bmp
# /kaggle/input/iit-delhi/L/825.bmp
# /kaggle/input/iit-delhi/L/135.bmp
# /kaggle/input/iit-delhi/L/44.bmp
# /kaggle/input/iit-delhi/L/2172.bmp
# /kaggle/input/iit-delhi/L/2111.bmp
# /kaggle/input/iit-delhi/L/1105.bmp
# /kaggle/input/iit-delhi/L/1964.bmp
# /kaggle/input/iit-delhi/L/873.bmp
# /kaggle/input/iit-delhi/L/1524.bmp
# /kaggle/input/iit-delhi/L/1584.bmp
# /kaggle/input/iit-delhi/L/1274.bmp
# /kaggle/input/iit-delhi/L/654.bmp
# /kaggle/input/iit-delhi/L/15.bmp
# /kaggle/input/iit-delhi/L/851.bmp
# /kaggle/input/iit-delhi/L/1845.bmp
# /kaggle/input/iit-delhi/L/73.bmp
# /kaggle/input/iit-delhi/L/985.bmp
# /kaggle/input/iit-delhi/L/1832.bmp
# /kaggle/input/iit-delhi/L/1472.bmp
# /kaggle/input/iit-delhi/L/2142.bmp
# /kaggle/input/iit-delhi/L/301.bmp
# /kaggle/input/iit-delhi/L/1685.bmp
# /kaggle/input/iit-delhi/L/2073.bmp
# /kaggle/input/iit-delhi/L/544.bmp
# /kaggle/input/iit-delhi/L/523.bmp
# /kaggle/input/iit-delhi/L/1231.bmp
# /kaggle/input/iit-delhi/L/1201.bmp
# /kaggle/input/iit-delhi/L/118.bmp
# /kaggle/input/iit-delhi/L/1422.bmp
# /kaggle/input/iit-delhi/L/1614.bmp
# /kaggle/input/iit-delhi/L/484.bmp
# /kaggle/input/iit-delhi/L/993.bmp
# /kaggle/input/iit-delhi/L/1174.bmp
# /kaggle/input/iit-delhi/L/1574.bmp
# /kaggle/input/iit-delhi/L/384.bmp
# /kaggle/input/iit-delhi/L/711.bmp
# /kaggle/input/iit-delhi/L/1751.bmp
# /kaggle/input/iit-delhi/L/1932.bmp
# /kaggle/input/iit-delhi/L/1571.bmp
# /kaggle/input/iit-delhi/L/1732.bmp
# /kaggle/input/iit-delhi/L/174.bmp
# /kaggle/input/iit-delhi/L/55.bmp
# /kaggle/input/iit-delhi/L/705.bmp
# /kaggle/input/iit-delhi/L/754.bmp
# /kaggle/input/iit-delhi/L/624.bmp
# /kaggle/input/iit-delhi/L/1725.bmp
# /kaggle/input/iit-delhi/L/117.bmp
# /kaggle/input/iit-delhi/L/1533.bmp
# /kaggle/input/iit-delhi/L/1794.bmp
# /kaggle/input/iit-delhi/L/1844.bmp
# /kaggle/input/iit-delhi/L/273.bmp
# /kaggle/input/iit-delhi/L/1522.bmp
# /kaggle/input/iit-delhi/L/1083.bmp
# /kaggle/input/iit-delhi/L/844.bmp
# /kaggle/input/iit-delhi/L/2044.bmp
# /kaggle/input/iit-delhi/L/1905.bmp
# /kaggle/input/iit-delhi/L/1904.bmp
# /kaggle/input/iit-delhi/L/2212.bmp
# /kaggle/input/iit-delhi/L/26.bmp
# /kaggle/input/iit-delhi/L/1723.bmp
# /kaggle/input/iit-delhi/L/933.bmp
# /kaggle/input/iit-delhi/L/1335.bmp
# /kaggle/input/iit-delhi/L/584.bmp
# /kaggle/input/iit-delhi/L/1404.bmp
# /kaggle/input/iit-delhi/L/2122.bmp
# /kaggle/input/iit-delhi/L/972.bmp
# /kaggle/input/iit-delhi/L/622.bmp
# /kaggle/input/iit-delhi/L/924.bmp
# /kaggle/input/iit-delhi/L/1312.bmp
# /kaggle/input/iit-delhi/L/1562.bmp
# /kaggle/input/iit-delhi/L/1982.bmp
# /kaggle/input/iit-delhi/L/1344.bmp
# /kaggle/input/iit-delhi/L/1542.bmp
# /kaggle/input/iit-delhi/L/78.bmp
# /kaggle/input/iit-delhi/L/1095.bmp
# /kaggle/input/iit-delhi/L/2125.bmp
# /kaggle/input/iit-delhi/L/2052.bmp
# /kaggle/input/iit-delhi/L/1504.bmp
# /kaggle/input/iit-delhi/L/565.bmp
# /kaggle/input/iit-delhi/L/1895.bmp
# /kaggle/input/iit-delhi/L/1043.bmp
# /kaggle/input/iit-delhi/L/1921.bmp
# /kaggle/input/iit-delhi/L/1081.bmp
# /kaggle/input/iit-delhi/L/1102.bmp
# /kaggle/input/iit-delhi/L/732.bmp
# /kaggle/input/iit-delhi/L/454.bmp
# /kaggle/input/iit-delhi/L/244.bmp
# /kaggle/input/iit-delhi/L/1894.bmp
# /kaggle/input/iit-delhi/L/1884.bmp
# /kaggle/input/iit-delhi/L/1172.bmp
# /kaggle/input/iit-delhi/L/361.bmp
# /kaggle/input/iit-delhi/L/2002.bmp
# /kaggle/input/iit-delhi/L/644.bmp
# /kaggle/input/iit-delhi/L/1801.bmp
# /kaggle/input/iit-delhi/L/1923.bmp
# /kaggle/input/iit-delhi/L/1415.bmp
# /kaggle/input/iit-delhi/L/27.bmp
# /kaggle/input/iit-delhi/L/106.bmp
# /kaggle/input/iit-delhi/L/1655.bmp
# /kaggle/input/iit-delhi/L/901.bmp
# /kaggle/input/iit-delhi/L/714.bmp
# /kaggle/input/iit-delhi/L/1922.bmp
# /kaggle/input/iit-delhi/L/575.bmp
# /kaggle/input/iit-delhi/L/2144.bmp
# /kaggle/input/iit-delhi/L/1902.bmp
# /kaggle/input/iit-delhi/L/963.bmp
# /kaggle/input/iit-delhi/L/824.bmp
# /kaggle/input/iit-delhi/L/1165.bmp
# /kaggle/input/iit-delhi/L/32.bmp
# /kaggle/input/iit-delhi/L/1602.bmp
# /kaggle/input/iit-delhi/L/193.bmp
# /kaggle/input/iit-delhi/L/2161.bmp
# /kaggle/input/iit-delhi/L/51.bmp
# /kaggle/input/iit-delhi/L/1943.bmp
# /kaggle/input/iit-delhi/L/181.bmp
# /kaggle/input/iit-delhi/L/2042.bmp
# /kaggle/input/iit-delhi/L/192.bmp
# /kaggle/input/iit-delhi/L/863.bmp
# /kaggle/input/iit-delhi/L/262.bmp
# /kaggle/input/iit-delhi/L/762.bmp
# /kaggle/input/iit-delhi/L/121.bmp
# /kaggle/input/iit-delhi/L/442.bmp
# /kaggle/input/iit-delhi/L/1461.bmp
# /kaggle/input/iit-delhi/L/231.bmp
# /kaggle/input/iit-delhi/L/2093.bmp
# /kaggle/input/iit-delhi/L/605.bmp
# /kaggle/input/iit-delhi/L/1092.bmp
# /kaggle/input/iit-delhi/L/154.bmp
# /kaggle/input/iit-delhi/L/282.bmp
# /kaggle/input/iit-delhi/L/1094.bmp
# /kaggle/input/iit-delhi/L/643.bmp
# /kaggle/input/iit-delhi/L/1185.bmp
# /kaggle/input/iit-delhi/L/1604.bmp
# /kaggle/input/iit-delhi/L/1051.bmp
# /kaggle/input/iit-delhi/L/2064.bmp
# /kaggle/input/iit-delhi/L/1114.bmp
# /kaggle/input/iit-delhi/L/1971.bmp
# /kaggle/input/iit-delhi/L/1863.bmp
# /kaggle/input/iit-delhi/L/1022.bmp
# /kaggle/input/iit-delhi/L/874.bmp
# /kaggle/input/iit-delhi/L/142.bmp
# /kaggle/input/iit-delhi/L/1695.bmp
# /kaggle/input/iit-delhi/L/814.bmp
# /kaggle/input/iit-delhi/L/1841.bmp
# /kaggle/input/iit-delhi/L/191.bmp
# /kaggle/input/iit-delhi/L/723.bmp
# /kaggle/input/iit-delhi/L/153.bmp
# /kaggle/input/iit-delhi/L/284.bmp
# /kaggle/input/iit-delhi/L/2025.bmp
# /kaggle/input/iit-delhi/L/464.bmp
# /kaggle/input/iit-delhi/L/2085.bmp
# /kaggle/input/iit-delhi/L/1691.bmp
# /kaggle/input/iit-delhi/L/1903.bmp
# /kaggle/input/iit-delhi/L/841.bmp
# /kaggle/input/iit-delhi/L/1961.bmp
# /kaggle/input/iit-delhi/L/22.bmp
# /kaggle/input/iit-delhi/L/1601.bmp
# /kaggle/input/iit-delhi/L/414.bmp
# /kaggle/input/iit-delhi/L/653.bmp
# /kaggle/input/iit-delhi/L/164.bmp
# /kaggle/input/iit-delhi/L/1901.bmp
# /kaggle/input/iit-delhi/L/1211.bmp
# /kaggle/input/iit-delhi/L/1215.bmp
# /kaggle/input/iit-delhi/L/272.bmp
# /kaggle/input/iit-delhi/L/1024.bmp
# /kaggle/input/iit-delhi/L/71.bmp
# /kaggle/input/iit-delhi/L/2154.bmp
# /kaggle/input/iit-delhi/L/104.bmp
# /kaggle/input/iit-delhi/L/425.bmp
# /kaggle/input/iit-delhi/L/2153.bmp
# /kaggle/input/iit-delhi/L/1243.bmp
# /kaggle/input/iit-delhi/L/1062.bmp
# /kaggle/input/iit-delhi/L/914.bmp
# /kaggle/input/iit-delhi/L/794.bmp
# /kaggle/input/iit-delhi/L/1014.bmp
# /kaggle/input/iit-delhi/L/1411.bmp
# /kaggle/input/iit-delhi/L/245.bmp
# /kaggle/input/iit-delhi/L/525.bmp
# /kaggle/input/iit-delhi/L/433.bmp
# /kaggle/input/iit-delhi/L/2072.bmp
# /kaggle/input/iit-delhi/L/1373.bmp
# /kaggle/input/iit-delhi/L/1623.bmp
# /kaggle/input/iit-delhi/L/1873.bmp
# /kaggle/input/iit-delhi/L/2164.bmp
# /kaggle/input/iit-delhi/L/1633.bmp
# /kaggle/input/iit-delhi/L/116.bmp
# /kaggle/input/iit-delhi/L/1853.bmp
# /kaggle/input/iit-delhi/L/1554.bmp
# /kaggle/input/iit-delhi/L/1591.bmp
# /kaggle/input/iit-delhi/L/482.bmp
# /kaggle/input/iit-delhi/L/1632.bmp
# /kaggle/input/iit-delhi/L/1531.bmp
# /kaggle/input/iit-delhi/L/945.bmp
# /kaggle/input/iit-delhi/L/33.bmp
# /kaggle/input/iit-delhi/L/2083.bmp
# /kaggle/input/iit-delhi/L/54.bmp
# /kaggle/input/iit-delhi/L/1823.bmp
# /kaggle/input/iit-delhi/L/1235.bmp
# /kaggle/input/iit-delhi/L/474.bmp
# /kaggle/input/iit-delhi/L/741.bmp
# /kaggle/input/iit-delhi/L/1101.bmp
# /kaggle/input/iit-delhi/L/642.bmp
# /kaggle/input/iit-delhi/L/415.bmp
# /kaggle/input/iit-delhi/L/965.bmp
# /kaggle/input/iit-delhi/L/1182.bmp
# /kaggle/input/iit-delhi/L/1824.bmp
# /kaggle/input/iit-delhi/L/2173.bmp
# /kaggle/input/iit-delhi/L/1434.bmp
# /kaggle/input/iit-delhi/L/1291.bmp
# /kaggle/input/iit-delhi/L/1481.bmp
# /kaggle/input/iit-delhi/L/983.bmp
# /kaggle/input/iit-delhi/L/1755.bmp
# /kaggle/input/iit-delhi/L/385.bmp
# /kaggle/input/iit-delhi/L/1154.bmp
# /kaggle/input/iit-delhi/L/694.bmp
# /kaggle/input/iit-delhi/L/2205.bmp
# /kaggle/input/iit-delhi/L/1734.bmp
# /kaggle/input/iit-delhi/L/292.bmp
# /kaggle/input/iit-delhi/L/275.bmp
# /kaggle/input/iit-delhi/L/1111.bmp
# /kaggle/input/iit-delhi/L/602.bmp
# /kaggle/input/iit-delhi/L/1463.bmp
# /kaggle/input/iit-delhi/L/17.bmp
# /kaggle/input/iit-delhi/L/145.bmp
# /kaggle/input/iit-delhi/L/472.bmp
# /kaggle/input/iit-delhi/L/8.bmp
# /kaggle/input/iit-delhi/L/1091.bmp
# /kaggle/input/iit-delhi/L/405.bmp
# /kaggle/input/iit-delhi/L/2051.bmp
# /kaggle/input/iit-delhi/L/1073.bmp
# /kaggle/input/iit-delhi/L/1253.bmp
# /kaggle/input/iit-delhi/L/1812.bmp
# /kaggle/input/iit-delhi/L/2233.bmp
# /kaggle/input/iit-delhi/L/2182.bmp
# /kaggle/input/iit-delhi/L/1153.bmp
# /kaggle/input/iit-delhi/L/175.bmp
# /kaggle/input/iit-delhi/L/13.bmp
# /kaggle/input/iit-delhi/L/524.bmp
# /kaggle/input/iit-delhi/L/1372.bmp
# /kaggle/input/iit-delhi/L/1665.bmp
# /kaggle/input/iit-delhi/L/751.bmp
# /kaggle/input/iit-delhi/L/894.bmp
# /kaggle/input/iit-delhi/L/634.bmp
# /kaggle/input/iit-delhi/L/1983.bmp
# /kaggle/input/iit-delhi/L/1852.bmp
# /kaggle/input/iit-delhi/L/354.bmp
# /kaggle/input/iit-delhi/L/1292.bmp
# /kaggle/input/iit-delhi/L/1103.bmp
# /kaggle/input/iit-delhi/L/543.bmp
# /kaggle/input/iit-delhi/L/1981.bmp
# /kaggle/input/iit-delhi/L/1145.bmp
# /kaggle/input/iit-delhi/L/1782.bmp
# /kaggle/input/iit-delhi/L/1962.bmp
# /kaggle/input/iit-delhi/L/493.bmp
# /kaggle/input/iit-delhi/L/1642.bmp
# /kaggle/input/iit-delhi/L/252.bmp
# /kaggle/input/iit-delhi/L/1001.bmp
# /kaggle/input/iit-delhi/L/1663.bmp
# /kaggle/input/iit-delhi/L/2034.bmp
# /kaggle/input/iit-delhi/L/465.bmp
# /kaggle/input/iit-delhi/L/875.bmp
# /kaggle/input/iit-delhi/L/1611.bmp
# /kaggle/input/iit-delhi/L/905.bmp
# /kaggle/input/iit-delhi/L/274.bmp
# /kaggle/input/iit-delhi/L/2115.bmp
# /kaggle/input/iit-delhi/L/1645.bmp
# /kaggle/input/iit-delhi/L/352.bmp
# /kaggle/input/iit-delhi/L/2021.bmp
# /kaggle/input/iit-delhi/L/110.bmp
# /kaggle/input/iit-delhi/L/2194.bmp
# /kaggle/input/iit-delhi/L/1311.bmp
# /kaggle/input/iit-delhi/L/1575.bmp
# /kaggle/input/iit-delhi/L/1395.bmp
# /kaggle/input/iit-delhi/L/954.bmp
# /kaggle/input/iit-delhi/L/1774.bmp
# /kaggle/input/iit-delhi/L/2054.bmp
# /kaggle/input/iit-delhi/L/952.bmp
# /kaggle/input/iit-delhi/L/2033.bmp
# /kaggle/input/iit-delhi/L/1753.bmp
# /kaggle/input/iit-delhi/L/373.bmp
# /kaggle/input/iit-delhi/L/592.bmp
# /kaggle/input/iit-delhi/L/773.bmp
# /kaggle/input/iit-delhi/L/2112.bmp
# /kaggle/input/iit-delhi/L/1414.bmp
# /kaggle/input/iit-delhi/L/664.bmp
# /kaggle/input/iit-delhi/L/2123.bmp
# /kaggle/input/iit-delhi/L/1831.bmp
# /kaggle/input/iit-delhi/L/1911.bmp
# /kaggle/input/iit-delhi/L/555.bmp
# /kaggle/input/iit-delhi/L/105.bmp
# /kaggle/input/iit-delhi/L/1223.bmp
# /kaggle/input/iit-delhi/L/1142.bmp
# /kaggle/input/iit-delhi/L/854.bmp
# /kaggle/input/iit-delhi/L/492.bmp
# /kaggle/input/iit-delhi/L/2141.bmp
# /kaggle/input/iit-delhi/L/34.bmp
# /kaggle/input/iit-delhi/L/1241.bmp
# /kaggle/input/iit-delhi/L/343.bmp
# /kaggle/input/iit-delhi/L/404.bmp
# /kaggle/input/iit-delhi/L/471.bmp
# /kaggle/input/iit-delhi/L/24.bmp
# /kaggle/input/iit-delhi/L/43.bmp
# /kaggle/input/iit-delhi/L/2185.bmp
# /kaggle/input/iit-delhi/L/302.bmp
# /kaggle/input/iit-delhi/L/91.bmp
# /kaggle/input/iit-delhi/L/1714.bmp
# /kaggle/input/iit-delhi/L/1342.bmp
# /kaggle/input/iit-delhi/L/1795.bmp
# /kaggle/input/iit-delhi/L/1033.bmp
# /kaggle/input/iit-delhi/L/281.bmp
# /kaggle/input/iit-delhi/L/1331.bmp
# /kaggle/input/iit-delhi/L/382.bmp
# /kaggle/input/iit-delhi/L/5.bmp
# /kaggle/input/iit-delhi/L/2124.bmp
# /kaggle/input/iit-delhi/L/1563.bmp
# /kaggle/input/iit-delhi/L/1855.bmp
# /kaggle/input/iit-delhi/L/264.bmp
# /kaggle/input/iit-delhi/L/11.bmp
# /kaggle/input/iit-delhi/L/61.bmp
# /kaggle/input/iit-delhi/L/2163.bmp
# /kaggle/input/iit-delhi/L/943.bmp
# /kaggle/input/iit-delhi/L/1065.bmp
# /kaggle/input/iit-delhi/L/152.bmp
# /kaggle/input/iit-delhi/L/19.bmp
# /kaggle/input/iit-delhi/L/165.bmp
# /kaggle/input/iit-delhi/L/895.bmp
# /kaggle/input/iit-delhi/L/41.bmp
# /kaggle/input/iit-delhi/L/1343.bmp
# /kaggle/input/iit-delhi/L/161.bmp
# /kaggle/input/iit-delhi/L/835.bmp
# /kaggle/input/iit-delhi/L/561.bmp
# /kaggle/input/iit-delhi/L/263.bmp
# /kaggle/input/iit-delhi/L/1772.bmp
# /kaggle/input/iit-delhi/L/531.bmp
# /kaggle/input/iit-delhi/L/1744.bmp
# /kaggle/input/iit-delhi/L/2075.bmp
# /kaggle/input/iit-delhi/L/1281.bmp
# /kaggle/input/iit-delhi/L/991.bmp
# /kaggle/input/iit-delhi/L/1864.bmp
# /kaggle/input/iit-delhi/L/1375.bmp
# /kaggle/input/iit-delhi/L/581.bmp
# /kaggle/input/iit-delhi/L/344.bmp
# /kaggle/input/iit-delhi/L/1003.bmp
# /kaggle/input/iit-delhi/L/775.bmp
# /kaggle/input/iit-delhi/L/1514.bmp
# /kaggle/input/iit-delhi/L/35.bmp
# /kaggle/input/iit-delhi/L/1662.bmp
# /kaggle/input/iit-delhi/L/342.bmp
# /kaggle/input/iit-delhi/L/1944.bmp
# /kaggle/input/iit-delhi/L/1125.bmp
# /kaggle/input/iit-delhi/L/743.bmp
# /kaggle/input/iit-delhi/L/53.bmp
# /kaggle/input/iit-delhi/L/1881.bmp
# /kaggle/input/iit-delhi/L/173.bmp
# /kaggle/input/iit-delhi/L/431.bmp
# /kaggle/input/iit-delhi/L/992.bmp
# /kaggle/input/iit-delhi/L/615.bmp
# /kaggle/input/iit-delhi/L/1515.bmp
# /kaggle/input/iit-delhi/L/82.bmp
# /kaggle/input/iit-delhi/L/1113.bmp
# /kaggle/input/iit-delhi/L/1161.bmp
# /kaggle/input/iit-delhi/L/2134.bmp
# /kaggle/input/iit-delhi/L/1465.bmp
# /kaggle/input/iit-delhi/L/1264.bmp
# /kaggle/input/iit-delhi/L/203.bmp
# /kaggle/input/iit-delhi/L/1204.bmp
# /kaggle/input/iit-delhi/L/1945.bmp
# /kaggle/input/iit-delhi/L/673.bmp
# /kaggle/input/iit-delhi/L/1323.bmp
# /kaggle/input/iit-delhi/L/1721.bmp
# /kaggle/input/iit-delhi/L/25.bmp
# /kaggle/input/iit-delhi/L/1314.bmp
# /kaggle/input/iit-delhi/L/1455.bmp
# /kaggle/input/iit-delhi/L/351.bmp
# /kaggle/input/iit-delhi/L/1635.bmp
# /kaggle/input/iit-delhi/L/411.bmp
# /kaggle/input/iit-delhi/L/2175.bmp
# /kaggle/input/iit-delhi/L/1025.bmp
# /kaggle/input/iit-delhi/L/80.bmp
# /kaggle/input/iit-delhi/L/2192.bmp
# /kaggle/input/iit-delhi/L/935.bmp
# /kaggle/input/iit-delhi/L/1433.bmp
# /kaggle/input/iit-delhi/L/64.bmp
# /kaggle/input/iit-delhi/L/931.bmp
# /kaggle/input/iit-delhi/L/2213.bmp
# /kaggle/input/iit-delhi/L/2094.bmp
# /kaggle/input/iit-delhi/L/1641.bmp
# /kaggle/input/iit-delhi/L/1545.bmp
# /kaggle/input/iit-delhi/L/1155.bmp
# /kaggle/input/iit-delhi/L/109.bmp
# /kaggle/input/iit-delhi/L/563.bmp
# /kaggle/input/iit-delhi/L/994.bmp
# /kaggle/input/iit-delhi/L/1675.bmp
# /kaggle/input/iit-delhi/L/604.bmp
# /kaggle/input/iit-delhi/L/1042.bmp
# /kaggle/input/iit-delhi/L/127.bmp
# /kaggle/input/iit-delhi/L/715.bmp
# /kaggle/input/iit-delhi/L/1391.bmp
# /kaggle/input/iit-delhi/L/1953.bmp
# /kaggle/input/iit-delhi/L/434.bmp
# /kaggle/input/iit-delhi/L/1255.bmp
# /kaggle/input/iit-delhi/L/314.bmp
# /kaggle/input/iit-delhi/L/126.bmp
# /kaggle/input/iit-delhi/L/98.bmp
# /kaggle/input/iit-delhi/L/1403.bmp
# /kaggle/input/iit-delhi/L/141.bmp
# /kaggle/input/iit-delhi/L/614.bmp
# /kaggle/input/iit-delhi/L/89.bmp
# /kaggle/input/iit-delhi/L/79.bmp
# /kaggle/input/iit-delhi/L/67.bmp
# /kaggle/input/iit-delhi/L/1935.bmp
# /kaggle/input/iit-delhi/L/951.bmp
# /kaggle/input/iit-delhi/L/1365.bmp
# /kaggle/input/iit-delhi/L/9.bmp
# /kaggle/input/iit-delhi/L/1711.bmp
# /kaggle/input/iit-delhi/L/1842.bmp
# /kaggle/input/iit-delhi/L/1605.bmp
# /kaggle/input/iit-delhi/L/681.bmp
# /kaggle/input/iit-delhi/L/683.bmp
# /kaggle/input/iit-delhi/L/594.bmp
# /kaggle/input/iit-delhi/L/81.bmp
# /kaggle/input/iit-delhi/L/903.bmp
# /kaggle/input/iit-delhi/L/2232.bmp
# /kaggle/input/iit-delhi/L/522.bmp
# /kaggle/input/iit-delhi/L/982.bmp
# /kaggle/input/iit-delhi/L/975.bmp
# /kaggle/input/iit-delhi/L/2195.bmp
# /kaggle/input/iit-delhi/L/2065.bmp
# /kaggle/input/iit-delhi/L/392.bmp
# /kaggle/input/iit-delhi/L/234.bmp
# /kaggle/input/iit-delhi/L/123.bmp
# /kaggle/input/iit-delhi/L/1553.bmp
# /kaggle/input/iit-delhi/L/1875.bmp
# /kaggle/input/iit-delhi/L/1592.bmp
# /kaggle/input/iit-delhi/L/364.bmp
# /kaggle/input/iit-delhi/L/2121.bmp
# /kaggle/input/iit-delhi/L/734.bmp
# /kaggle/input/iit-delhi/L/1045.bmp
# /kaggle/input/iit-delhi/L/103.bmp
# /kaggle/input/iit-delhi/L/1013.bmp
# /kaggle/input/iit-delhi/L/1132.bmp
# /kaggle/input/iit-delhi/L/2135.bmp
# /kaggle/input/iit-delhi/L/795.bmp
# /kaggle/input/iit-delhi/L/423.bmp
# /kaggle/input/iit-delhi/L/1693.bmp
# /kaggle/input/iit-delhi/L/1775.bmp
# /kaggle/input/iit-delhi/L/1355.bmp
# /kaggle/input/iit-delhi/L/185.bmp
# /kaggle/input/iit-delhi/L/902.bmp
# /kaggle/input/iit-delhi/L/2043.bmp
# /kaggle/input/iit-delhi/L/821.bmp
# /kaggle/input/iit-delhi/L/182.bmp
# /kaggle/input/iit-delhi/L/412.bmp
# /kaggle/input/iit-delhi/L/403.bmp
# /kaggle/input/iit-delhi/L/1451.bmp
# /kaggle/input/iit-delhi/L/1771.bmp
# /kaggle/input/iit-delhi/L/1392.bmp
# /kaggle/input/iit-delhi/L/2101.bmp
# /kaggle/input/iit-delhi/L/2071.bmp
# /kaggle/input/iit-delhi/L/1491.bmp
# /kaggle/input/iit-delhi/L/1265.bmp
# /kaggle/input/iit-delhi/L/1582.bmp
# /kaggle/input/iit-delhi/L/1381.bmp
# /kaggle/input/iit-delhi/L/1093.bmp
# /kaggle/input/iit-delhi/L/1082.bmp
# /kaggle/input/iit-delhi/L/1054.bmp
# /kaggle/input/iit-delhi/L/68.bmp
# /kaggle/input/iit-delhi/L/66.bmp
# /kaggle/input/iit-delhi/L/885.bmp
# /kaggle/input/iit-delhi/L/1702.bmp
# /kaggle/input/iit-delhi/L/1535.bmp
# /kaggle/input/iit-delhi/L/744.bmp
# /kaggle/input/iit-delhi/L/2184.bmp
# /kaggle/input/iit-delhi/L/1651.bmp
# /kaggle/input/iit-delhi/L/1482.bmp
# /kaggle/input/iit-delhi/L/1131.bmp
# /kaggle/input/iit-delhi/L/2181.bmp
# /kaggle/input/iit-delhi/L/453.bmp
# /kaggle/input/iit-delhi/L/1822.bmp
# /kaggle/input/iit-delhi/L/1023.bmp
# /kaggle/input/iit-delhi/L/333.bmp
# /kaggle/input/iit-delhi/L/1233.bmp
# /kaggle/input/iit-delhi/L/124.bmp
# /kaggle/input/iit-delhi/L/761.bmp
# /kaggle/input/iit-delhi/L/1634.bmp
# /kaggle/input/iit-delhi/L/2225.bmp
# /kaggle/input/iit-delhi/L/571.bmp
# /kaggle/input/iit-delhi/L/675.bmp
# /kaggle/input/iit-delhi/L/1991.bmp
# /kaggle/input/iit-delhi/L/422.bmp
# /kaggle/input/iit-delhi/L/1075.bmp
# /kaggle/input/iit-delhi/L/46.bmp
# /kaggle/input/iit-delhi/L/1072.bmp
# /kaggle/input/iit-delhi/L/1195.bmp
# /kaggle/input/iit-delhi/L/294.bmp
# /kaggle/input/iit-delhi/L/3.bmp
# /kaggle/input/iit-delhi/L/1681.bmp
# /kaggle/input/iit-delhi/L/1551.bmp
# /kaggle/input/iit-delhi/L/1544.bmp
# /kaggle/input/iit-delhi/L/355.bmp
# /kaggle/input/iit-delhi/L/1252.bmp
# /kaggle/input/iit-delhi/L/1284.bmp
# /kaggle/input/iit-delhi/L/1871.bmp
# /kaggle/input/iit-delhi/L/511.bmp
# /kaggle/input/iit-delhi/L/261.bmp
# /kaggle/input/iit-delhi/L/702.bmp
# /kaggle/input/iit-delhi/L/1724.bmp
# /kaggle/input/iit-delhi/L/883.bmp
# /kaggle/input/iit-delhi/L/1244.bmp
# /kaggle/input/iit-delhi/L/793.bmp
# /kaggle/input/iit-delhi/L/1305.bmp
# /kaggle/input/iit-delhi/L/10.bmp
# /kaggle/input/iit-delhi/L/52.bmp
# /kaggle/input/iit-delhi/L/2102.bmp
# /kaggle/input/iit-delhi/L/253.bmp
# /kaggle/input/iit-delhi/L/2211.bmp
# /kaggle/input/iit-delhi/L/335.bmp
# /kaggle/input/iit-delhi/L/1682.bmp
# /kaggle/input/iit-delhi/L/233.bmp
# /kaggle/input/iit-delhi/L/1084.bmp
# /kaggle/input/iit-delhi/L/36.bmp
# /kaggle/input/iit-delhi/L/501.bmp
# /kaggle/input/iit-delhi/L/845.bmp
# /kaggle/input/iit-delhi/L/1583.bmp
# /kaggle/input/iit-delhi/L/1745.bmp
# /kaggle/input/iit-delhi/L/391.bmp
# /kaggle/input/iit-delhi/L/1511.bmp
# /kaggle/input/iit-delhi/L/1972.bmp
# /kaggle/input/iit-delhi/L/1181.bmp
# /kaggle/input/iit-delhi/L/753.bmp
# /kaggle/input/iit-delhi/L/591.bmp
# /kaggle/input/iit-delhi/L/1843.bmp
# /kaggle/input/iit-delhi/L/1565.bmp
# /kaggle/input/iit-delhi/L/1704.bmp
# /kaggle/input/iit-delhi/L/1555.bmp
# /kaggle/input/iit-delhi/L/2162.bmp
# /kaggle/input/iit-delhi/L/755.bmp
# /kaggle/input/iit-delhi/L/21.bmp
# /kaggle/input/iit-delhi/L/195.bmp
# /kaggle/input/iit-delhi/L/7.bmp
# /kaggle/input/iit-delhi/L/2003.bmp
# /kaggle/input/iit-delhi/L/88.bmp
# /kaggle/input/iit-delhi/L/92.bmp
# /kaggle/input/iit-delhi/L/31.bmp
# /kaggle/input/iit-delhi/L/2001.bmp
# /kaggle/input/iit-delhi/L/1851.bmp
# /kaggle/input/iit-delhi/L/583.bmp
# /kaggle/input/iit-delhi/L/535.bmp
# /kaggle/input/iit-delhi/L/183.bmp
# /kaggle/input/iit-delhi/L/862.bmp
# /kaggle/input/iit-delhi/L/2132.bmp
# /kaggle/input/iit-delhi/L/912.bmp
# /kaggle/input/iit-delhi/L/205.bmp
# /kaggle/input/iit-delhi/L/1304.bmp
# /kaggle/input/iit-delhi/L/303.bmp
# /kaggle/input/iit-delhi/L/785.bmp
# /kaggle/input/iit-delhi/L/224.bmp
# /kaggle/input/iit-delhi/L/49.bmp
# /kaggle/input/iit-delhi/L/1275.bmp
# /kaggle/input/iit-delhi/L/1763.bmp
# /kaggle/input/iit-delhi/L/293.bmp
# /kaggle/input/iit-delhi/L/57.bmp
# /kaggle/input/iit-delhi/L/2053.bmp
# /kaggle/input/iit-delhi/L/546.bmp
# /kaggle/input/iit-delhi/L/1294.bmp
# /kaggle/input/iit-delhi/L/1683.bmp
# /kaggle/input/iit-delhi/L/2133.bmp
# /kaggle/input/iit-delhi/L/953.bmp
# /kaggle/input/iit-delhi/L/20.bmp
# /kaggle/input/iit-delhi/L/223.bmp
# /kaggle/input/iit-delhi/L/745.bmp
# /kaggle/input/iit-delhi/L/212.bmp
# /kaggle/input/iit-delhi/L/1191.bmp
# /kaggle/input/iit-delhi/L/1362.bmp
# /kaggle/input/iit-delhi/L/122.bmp
# /kaggle/input/iit-delhi/L/1055.bmp
# /kaggle/input/iit-delhi/L/130.bmp
# /kaggle/input/iit-delhi/L/371.bmp
# /kaggle/input/iit-delhi/L/194.bmp
# /kaggle/input/iit-delhi/L/925.bmp
# /kaggle/input/iit-delhi/L/1261.bmp
# /kaggle/input/iit-delhi/L/50.bmp
# /kaggle/input/iit-delhi/L/1835.bmp
# /kaggle/input/iit-delhi/L/2005.bmp
# /kaggle/input/iit-delhi/L/1425.bmp
# /kaggle/input/iit-delhi/L/393.bmp
# /kaggle/input/iit-delhi/L/461.bmp
# /kaggle/input/iit-delhi/L/1124.bmp
# /kaggle/input/iit-delhi/L/1892.bmp
# /kaggle/input/iit-delhi/L/1862.bmp
# /kaggle/input/iit-delhi/L/1643.bmp
# /kaggle/input/iit-delhi/L/2191.bmp
# /kaggle/input/iit-delhi/L/662.bmp
# /kaggle/input/iit-delhi/L/771.bmp
# /kaggle/input/iit-delhi/L/1444.bmp
# /kaggle/input/iit-delhi/L/1285.bmp
# /kaggle/input/iit-delhi/L/1733.bmp
# /kaggle/input/iit-delhi/L/1203.bmp
# /kaggle/input/iit-delhi/L/921.bmp
# /kaggle/input/iit-delhi/L/1621.bmp
# /kaggle/input/iit-delhi/L/1874.bmp
# /kaggle/input/iit-delhi/L/56.bmp
# /kaggle/input/iit-delhi/L/1272.bmp
# /kaggle/input/iit-delhi/L/2223.bmp
# /kaggle/input/iit-delhi/L/295.bmp
# /kaggle/input/iit-delhi/L/1934.bmp
# /kaggle/input/iit-delhi/L/1593.bmp
# /kaggle/input/iit-delhi/L/813.bmp
# /kaggle/input/iit-delhi/L/1183.bmp
# /kaggle/input/iit-delhi/L/641.bmp
# /kaggle/input/iit-delhi/L/1122.bmp
# /kaggle/input/iit-delhi/L/1074.bmp
# /kaggle/input/iit-delhi/L/1742.bmp
# /kaggle/input/iit-delhi/L/882.bmp
# /kaggle/input/iit-delhi/L/1435.bmp
# /kaggle/input/iit-delhi/L/163.bmp
# /kaggle/input/iit-delhi/L/595.bmp
# /kaggle/input/iit-delhi/L/432.bmp
# /kaggle/input/iit-delhi/L/834.bmp
# /kaggle/input/iit-delhi/L/621.bmp
# /kaggle/input/iit-delhi/L/2095.bmp
# /kaggle/input/iit-delhi/L/833.bmp
# /kaggle/input/iit-delhi/L/842.bmp
# /kaggle/input/iit-delhi/L/1973.bmp
# /kaggle/input/iit-delhi/L/1854.bmp
# /kaggle/input/iit-delhi/L/1492.bmp
# /kaggle/input/iit-delhi/L/345.bmp
# /kaggle/input/iit-delhi/L/812.bmp
# /kaggle/input/iit-delhi/L/505.bmp
# /kaggle/input/iit-delhi/L/1224.bmp
# /kaggle/input/iit-delhi/L/265.bmp
# /kaggle/input/iit-delhi/L/1963.bmp
# /kaggle/input/iit-delhi/L/1561.bmp
# /kaggle/input/iit-delhi/L/801.bmp
# /kaggle/input/iit-delhi/L/48.bmp
# /kaggle/input/iit-delhi/L/661.bmp
# /kaggle/input/iit-delhi/L/1143.bmp
# /kaggle/input/iit-delhi/L/1715.bmp
# /kaggle/input/iit-delhi/L/1322.bmp
# /kaggle/input/iit-delhi/L/1941.bmp
# /kaggle/input/iit-delhi/L/394.bmp
# /kaggle/input/iit-delhi/L/2152.bmp
# /kaggle/input/iit-delhi/L/1891.bmp
# /kaggle/input/iit-delhi/L/504.bmp
# /kaggle/input/iit-delhi/L/481.bmp
# /kaggle/input/iit-delhi/L/445.bmp
# /kaggle/input/iit-delhi/L/2183.bmp
# /kaggle/input/iit-delhi/L/1872.bmp
# /kaggle/input/iit-delhi/L/1502.bmp
# /kaggle/input/iit-delhi/L/76.bmp
# /kaggle/input/iit-delhi/L/1951.bmp
# /kaggle/input/iit-delhi/L/1505.bmp
# /kaggle/input/iit-delhi/L/30.bmp
# /kaggle/input/iit-delhi/L/552.bmp
# /kaggle/input/iit-delhi/L/1585.bmp
# /kaggle/input/iit-delhi/L/1834.bmp
# /kaggle/input/iit-delhi/L/1454.bmp
# /kaggle/input/iit-delhi/L/1615.bmp
# /kaggle/input/iit-delhi/L/94.bmp
# /kaggle/input/iit-delhi/L/1313.bmp
# /kaggle/input/iit-delhi/L/1503.bmp
# /kaggle/input/iit-delhi/L/315.bmp
# /kaggle/input/iit-delhi/L/2105.bmp
# /kaggle/input/iit-delhi/L/1332.bmp
# /kaggle/input/iit-delhi/L/613.bmp
# /kaggle/input/iit-delhi/L/1271.bmp
# /kaggle/input/iit-delhi/L/871.bmp
# /kaggle/input/iit-delhi/L/722.bmp
# /kaggle/input/iit-delhi/L/1134.bmp
# /kaggle/input/iit-delhi/L/77.bmp
# /kaggle/input/iit-delhi/L/2074.bmp
# /kaggle/input/iit-delhi/L/451.bmp
# /kaggle/input/iit-delhi/L/70.bmp
# /kaggle/input/iit-delhi/L/981.bmp
# /kaggle/input/iit-delhi/L/1041.bmp
# /kaggle/input/iit-delhi/L/1363.bmp
# /kaggle/input/iit-delhi/L/2235.bmp
# /kaggle/input/iit-delhi/L/1052.bmp
# /kaggle/input/iit-delhi/L/222.bmp
# /kaggle/input/iit-delhi/L/331.bmp
# /kaggle/input/iit-delhi/L/2032.bmp
# /kaggle/input/iit-delhi/L/803.bmp
# /kaggle/input/iit-delhi/L/2165.bmp
# /kaggle/input/iit-delhi/L/541.bmp
# /kaggle/input/iit-delhi/L/225.bmp
# /kaggle/input/iit-delhi/L/1815.bmp
# /kaggle/input/iit-delhi/L/1731.bmp
# /kaggle/input/iit-delhi/L/1761.bmp
# /kaggle/input/iit-delhi/L/2151.bmp
# /kaggle/input/iit-delhi/L/1985.bmp
# /kaggle/input/iit-delhi/L/1814.bmp
# /kaggle/input/iit-delhi/L/1115.bmp
# /kaggle/input/iit-delhi/L/1442.bmp
# /kaggle/input/iit-delhi/L/120.bmp
# /kaggle/input/iit-delhi/L/573.bmp
# /kaggle/input/iit-delhi/L/313.bmp
# /kaggle/input/iit-delhi/L/635.bmp
# /kaggle/input/iit-delhi/L/1952.bmp
# /kaggle/input/iit-delhi/L/1173.bmp
# /kaggle/input/iit-delhi/L/204.bmp
# /kaggle/input/iit-delhi/L/1445.bmp
# /kaggle/input/iit-delhi/L/1394.bmp
# /kaggle/input/iit-delhi/L/611.bmp
# /kaggle/input/iit-delhi/L/69.bmp
# /kaggle/input/iit-delhi/L/113.bmp
# /kaggle/input/iit-delhi/L/1121.bmp
# /kaggle/input/iit-delhi/L/792.bmp
# /kaggle/input/iit-delhi/L/38.bmp
# /kaggle/input/iit-delhi/L/1594.bmp
# /kaggle/input/iit-delhi/L/1793.bmp
# /kaggle/input/iit-delhi/L/473.bmp
# /kaggle/input/iit-delhi/L/1334.bmp
# /kaggle/input/iit-delhi/L/2055.bmp
# /kaggle/input/iit-delhi/L/864.bmp
# /kaggle/input/iit-delhi/L/911.bmp
# /kaggle/input/iit-delhi/L/1471.bmp
# /kaggle/input/iit-delhi/L/1035.bmp
# /kaggle/input/iit-delhi/L/1061.bmp
# /kaggle/input/iit-delhi/L/1213.bmp
# /kaggle/input/iit-delhi/L/2014.bmp
# /kaggle/input/iit-delhi/L/1992.bmp
# /kaggle/input/iit-delhi/L/63.bmp
# /kaggle/input/iitd-l/L_png/1017.png
# /kaggle/input/iitd-l/L_png/641.png
# /kaggle/input/iitd-l/L_png/1088.png
# /kaggle/input/iitd-l/L_png/173.png
# /kaggle/input/iitd-l/L_png/815.png
# /kaggle/input/iitd-l/L_png/491.png
# /kaggle/input/iitd-l/L_png/1084.png
# /kaggle/input/iitd-l/L_png/718.png
# /kaggle/input/iitd-l/L_png/709.png
# /kaggle/input/iitd-l/L_png/889.png
# /kaggle/input/iitd-l/L_png/379.png
# /kaggle/input/iitd-l/L_png/780.png
# /kaggle/input/iitd-l/L_png/248.png
# /kaggle/input/iitd-l/L_png/94.png
# /kaggle/input/iitd-l/L_png/480.png
# /kaggle/input/iitd-l/L_png/1145.png
# /kaggle/input/iitd-l/L_png/236.png
# /kaggle/input/iitd-l/L_png/1012.png
# /kaggle/input/iitd-l/L_png/771.png
# /kaggle/input/iitd-l/L_png/675.png
# /kaggle/input/iitd-l/L_png/340.png
# /kaggle/input/iitd-l/L_png/48.png
# /kaggle/input/iitd-l/L_png/513.png
# /kaggle/input/iitd-l/L_png/1037.png
# /kaggle/input/iitd-l/L_png/677.png
# /kaggle/input/iitd-l/L_png/350.png
# /kaggle/input/iitd-l/L_png/761.png
# /kaggle/input/iitd-l/L_png/314.png
# /kaggle/input/iitd-l/L_png/1023.png
# /kaggle/input/iitd-l/L_png/655.png
# /kaggle/input/iitd-l/L_png/227.png
# /kaggle/input/iitd-l/L_png/762.png
# /kaggle/input/iitd-l/L_png/726.png
# /kaggle/input/iitd-l/L_png/238.png
# /kaggle/input/iitd-l/L_png/61.png
# /kaggle/input/iitd-l/L_png/377.png
# /kaggle/input/iitd-l/L_png/581.png
# /kaggle/input/iitd-l/L_png/222.png
# /kaggle/input/iitd-l/L_png/330.png
# /kaggle/input/iitd-l/L_png/511.png
# /kaggle/input/iitd-l/L_png/579.png
# /kaggle/input/iitd-l/L_png/278.png
# /kaggle/input/iitd-l/L_png/927.png
# /kaggle/input/iitd-l/L_png/303.png
# /kaggle/input/iitd-l/L_png/37.png
# /kaggle/input/iitd-l/L_png/231.png
# /kaggle/input/iitd-l/L_png/1048.png
# /kaggle/input/iitd-l/L_png/645.png
# /kaggle/input/iitd-l/L_png/348.png
# /kaggle/input/iitd-l/L_png/449.png
# /kaggle/input/iitd-l/L_png/353.png
# /kaggle/input/iitd-l/L_png/621.png
# /kaggle/input/iitd-l/L_png/148.png
# /kaggle/input/iitd-l/L_png/990.png
# /kaggle/input/iitd-l/L_png/403.png
# /kaggle/input/iitd-l/L_png/1000.png
# /kaggle/input/iitd-l/L_png/352.png
# /kaggle/input/iitd-l/L_png/35.png
# /kaggle/input/iitd-l/L_png/232.png
# /kaggle/input/iitd-l/L_png/817.png
# /kaggle/input/iitd-l/L_png/334.png
# /kaggle/input/iitd-l/L_png/177.png
# /kaggle/input/iitd-l/L_png/1081.png
# /kaggle/input/iitd-l/L_png/142.png
# /kaggle/input/iitd-l/L_png/834.png
# /kaggle/input/iitd-l/L_png/1176.png
# /kaggle/input/iitd-l/L_png/754.png
# /kaggle/input/iitd-l/L_png/407.png
# /kaggle/input/iitd-l/L_png/104.png
# /kaggle/input/iitd-l/L_png/384.png
# /kaggle/input/iitd-l/L_png/376.png
# /kaggle/input/iitd-l/L_png/543.png
# /kaggle/input/iitd-l/L_png/737.png
# /kaggle/input/iitd-l/L_png/1156.png
# /kaggle/input/iitd-l/L_png/1004.png
# /kaggle/input/iitd-l/L_png/133.png
# /kaggle/input/iitd-l/L_png/70.png
# /kaggle/input/iitd-l/L_png/162.png
# /kaggle/input/iitd-l/L_png/419.png
# /kaggle/input/iitd-l/L_png/951.png
# /kaggle/input/iitd-l/L_png/940.png
# /kaggle/input/iitd-l/L_png/517.png
# /kaggle/input/iitd-l/L_png/1032.png
# /kaggle/input/iitd-l/L_png/398.png
# /kaggle/input/iitd-l/L_png/634.png
# /kaggle/input/iitd-l/L_png/186.png
# /kaggle/input/iitd-l/L_png/778.png
# /kaggle/input/iitd-l/L_png/73.png
# /kaggle/input/iitd-l/L_png/870.png
# /kaggle/input/iitd-l/L_png/933.png
# /kaggle/input/iitd-l/L_png/92.png
# /kaggle/input/iitd-l/L_png/542.png
# /kaggle/input/iitd-l/L_png/766.png
# /kaggle/input/iitd-l/L_png/315.png
# /kaggle/input/iitd-l/L_png/436.png
# /kaggle/input/iitd-l/L_png/359.png
# /kaggle/input/iitd-l/L_png/261.png
# /kaggle/input/iitd-l/L_png/901.png
# /kaggle/input/iitd-l/L_png/1096.png
# /kaggle/input/iitd-l/L_png/153.png
# /kaggle/input/iitd-l/L_png/167.png
# /kaggle/input/iitd-l/L_png/628.png
# /kaggle/input/iitd-l/L_png/506.png
# /kaggle/input/iitd-l/L_png/1147.png
# /kaggle/input/iitd-l/L_png/441.png
# /kaggle/input/iitd-l/L_png/928.png
# /kaggle/input/iitd-l/L_png/562.png
# /kaggle/input/iitd-l/L_png/681.png
# /kaggle/input/iitd-l/L_png/1064.png
# /kaggle/input/iitd-l/L_png/204.png
# /kaggle/input/iitd-l/L_png/646.png
# /kaggle/input/iitd-l/L_png/1179.png
# /kaggle/input/iitd-l/L_png/75.png
# /kaggle/input/iitd-l/L_png/1128.png
# /kaggle/input/iitd-l/L_png/296.png
# /kaggle/input/iitd-l/L_png/1072.png
# /kaggle/input/iitd-l/L_png/1123.png
# /kaggle/input/iitd-l/L_png/744.png
# /kaggle/input/iitd-l/L_png/538.png
# /kaggle/input/iitd-l/L_png/651.png
# /kaggle/input/iitd-l/L_png/899.png
# /kaggle/input/iitd-l/L_png/270.png
# /kaggle/input/iitd-l/L_png/89.png
# /kaggle/input/iitd-l/L_png/385.png
# /kaggle/input/iitd-l/L_png/768.png
# /kaggle/input/iitd-l/L_png/872.png
# /kaggle/input/iitd-l/L_png/338.png
# /kaggle/input/iitd-l/L_png/333.png
# /kaggle/input/iitd-l/L_png/164.png
# /kaggle/input/iitd-l/L_png/1168.png
# /kaggle/input/iitd-l/L_png/1118.png
# /kaggle/input/iitd-l/L_png/752.png
# /kaggle/input/iitd-l/L_png/550.png
# /kaggle/input/iitd-l/L_png/521.png
# /kaggle/input/iitd-l/L_png/11.png
# /kaggle/input/iitd-l/L_png/1036.png
# /kaggle/input/iitd-l/L_png/615.png
# /kaggle/input/iitd-l/L_png/416.png
# /kaggle/input/iitd-l/L_png/994.png
# /kaggle/input/iitd-l/L_png/881.png
# /kaggle/input/iitd-l/L_png/605.png
# /kaggle/input/iitd-l/L_png/707.png
# /kaggle/input/iitd-l/L_png/351.png
# /kaggle/input/iitd-l/L_png/1010.png
# /kaggle/input/iitd-l/L_png/213.png
# /kaggle/input/iitd-l/L_png/411.png
# /kaggle/input/iitd-l/L_png/505.png
# /kaggle/input/iitd-l/L_png/114.png
# /kaggle/input/iitd-l/L_png/930.png
# /kaggle/input/iitd-l/L_png/302.png
# /kaggle/input/iitd-l/L_png/185.png
# /kaggle/input/iitd-l/L_png/240.png
# /kaggle/input/iitd-l/L_png/811.png
# /kaggle/input/iitd-l/L_png/317.png
# /kaggle/input/iitd-l/L_png/1041.png
# /kaggle/input/iitd-l/L_png/281.png
# /kaggle/input/iitd-l/L_png/344.png
# /kaggle/input/iitd-l/L_png/457.png
# /kaggle/input/iitd-l/L_png/493.png
# /kaggle/input/iitd-l/L_png/759.png
# /kaggle/input/iitd-l/L_png/907.png
# /kaggle/input/iitd-l/L_png/1071.png
# /kaggle/input/iitd-l/L_png/362.png
# /kaggle/input/iitd-l/L_png/1148.png
# /kaggle/input/iitd-l/L_png/176.png
# /kaggle/input/iitd-l/L_png/660.png
# /kaggle/input/iitd-l/L_png/727.png
# /kaggle/input/iitd-l/L_png/95.png
# /kaggle/input/iitd-l/L_png/432.png
# /kaggle/input/iitd-l/L_png/895.png
# /kaggle/input/iitd-l/L_png/1161.png
# /kaggle/input/iitd-l/L_png/97.png
# /kaggle/input/iitd-l/L_png/124.png
# /kaggle/input/iitd-l/L_png/119.png
# /kaggle/input/iitd-l/L_png/256.png
# /kaggle/input/iitd-l/L_png/791.png
# /kaggle/input/iitd-l/L_png/654.png
# /kaggle/input/iitd-l/L_png/100.png
# /kaggle/input/iitd-l/L_png/211.png
# /kaggle/input/iitd-l/L_png/500.png
# /kaggle/input/iitd-l/L_png/322.png
# /kaggle/input/iitd-l/L_png/76.png
# /kaggle/input/iitd-l/L_png/193.png
# /kaggle/input/iitd-l/L_png/608.png
# /kaggle/input/iitd-l/L_png/191.png
# /kaggle/input/iitd-l/L_png/420.png
# /kaggle/input/iitd-l/L_png/528.png
# /kaggle/input/iitd-l/L_png/163.png
# /kaggle/input/iitd-l/L_png/31.png
# /kaggle/input/iitd-l/L_png/623.png
# /kaggle/input/iitd-l/L_png/969.png
# /kaggle/input/iitd-l/L_png/1097.png
# /kaggle/input/iitd-l/L_png/642.png
# /kaggle/input/iitd-l/L_png/825.png
# /kaggle/input/iitd-l/L_png/1122.png
# /kaggle/input/iitd-l/L_png/1018.png
# /kaggle/input/iitd-l/L_png/138.png
# /kaggle/input/iitd-l/L_png/629.png
# /kaggle/input/iitd-l/L_png/396.png
# /kaggle/input/iitd-l/L_png/4.png
# /kaggle/input/iitd-l/L_png/796.png
# /kaggle/input/iitd-l/L_png/844.png
# ...
# /kaggle/input/iitd-l/L_png/246.png
# /kaggle/input/iitd-l/L_png/195.png
# /kaggle/input/iitd-l/L_png/998.png
# /kaggle/input/iitd-l/L_png/105.png
# /kaggle/input/iitd-l/L_png/479.png
# /kaggle/input/iitd-l/L_png/612.png
# /kaggle/input/iitd-l/L_png/1092.png
# /kaggle/input/iitd-l/L_png/125.png
# /kaggle/input/iitd-l/L_png/121.png
# /kaggle/input/iitd-l/L_png/1026.png
# /kaggle/input/iitd-l/L_png/318.png
# /kaggle/input/iitd-l/L_png/832.png
# /kaggle/input/iitd-l/L_png/216.png
# /kaggle/input/iitd-l/L_png/656.png
# /kaggle/input/iitd-l/L_png/337.png
# /kaggle/input/iitd-l/L_png/69.png
# /kaggle/input/iitd-l/L_png/146.png
# /kaggle/input/iitd-l/L_png/991.png
# /kaggle/input/iitd-l/L_png/154.png
# /kaggle/input/iitd-l/L_png/637.png
# /kaggle/input/iitd-l/L_png/905.png
# /kaggle/input/iitd-l/L_png/1170.png
# /kaggle/input/iitd-l/L_png/1146.png
# /kaggle/input/iitd-l/L_png/267.png
# /kaggle/input/iitd-l/L_png/7.png
# /kaggle/input/iitd-l/L_png/1075.png
# /kaggle/input/iitd-l/L_png/663.png
# /kaggle/input/iitd-l/L_png/374.png
# /kaggle/input/iitd-l/L_png/1185.png
# /kaggle/input/iitd-l/L_png/366.png
# /kaggle/input/iitd-l/L_png/915.png
# /kaggle/input/iitd-l/L_png/241.png
# /kaggle/input/iitd-l/L_png/805.png
# /kaggle/input/iitd-l/L_png/188.png
# /kaggle/input/iitd-l/L_png/1173.png
# /kaggle/input/iitd-l/L_png/1098.png
# /kaggle/input/iitd-l/L_png/716.png
# /kaggle/input/iitd-l/L_png/86.png
# /kaggle/input/iitd-l/L_png/836.png
# /kaggle/input/iitd-l/L_png/776.png
# /kaggle/input/iitd-l/L_png/916.png
# /kaggle/input/iitd-l/L_png/894.png
# /kaggle/input/iitd-l/L_png/258.png
# /kaggle/input/iitd-l/L_png/838.png
# /kaggle/input/iitd-l/L_png/77.png
# /kaggle/input/iitd-l/L_png/1131.png
# /kaggle/input/iitd-l/L_png/1051.png
# /kaggle/input/iitd-l/L_png/498.png
# /kaggle/input/iitd-l/L_png/290.png
# /kaggle/input/iitd-l/L_png/29.png
# /kaggle/input/iitd-l/L_png/265.png
# /kaggle/input/iitd-l/L_png/638.png
# /kaggle/input/iitd-l/L_png/103.png
# /kaggle/input/iitd-l/L_png/1007.png
# /kaggle/input/iitd-l/L_png/882.png
# /kaggle/input/iitd-l/L_png/632.png
# /kaggle/input/iitd-l/L_png/72.png
# /kaggle/input/iitd-l/L_png/833.png
# /kaggle/input/iitd-l/L_png/144.png
# /kaggle/input/iitd-l/L_png/977.png
# /kaggle/input/iitd-l/L_png/298.png
# /kaggle/input/iitd-l/L_png/472.png
# /kaggle/input/iitd-l/L_png/503.png
# /kaggle/input/iitd-l/L_png/695.png
# /kaggle/input/iitd-l/L_png/644.png
# /kaggle/input/iitd-l/L_png/456.png
# /kaggle/input/iitd-l/L_png/540.png
# /kaggle/input/iitd-l/L_png/109.png
# /kaggle/input/iitd-l/L_png/496.png
# /kaggle/input/iitd-l/L_png/714.png
# /kaggle/input/iitd-l/L_png/697.png
# /kaggle/input/iitd-l/L_png/861.png
# /kaggle/input/iitd-l/L_png/224.png
# /kaggle/input/iitd-l/L_png/1015.png
# /kaggle/input/iitd-l/L_png/361.png
# /kaggle/input/iitd-l/L_png/753.png
# /kaggle/input/iitd-l/L_png/567.png
# /kaggle/input/iitd-l/L_png/1035.png
# /kaggle/input/iitd-l/L_png/526.png
# /kaggle/input/iitd-l/L_png/527.png
# /kaggle/input/iitd-l/L_png/71.png
# /kaggle/input/iitd-l/L_png/648.png
# /kaggle/input/iitd-l/L_png/595.png
# /kaggle/input/iitd-l/L_png/573.png
# /kaggle/input/iitd-l/L_png/74.png
# /kaggle/input/iitd-l/L_png/1001.png
# /kaggle/input/iitd-l/L_png/653.png
# /kaggle/input/iitd-l/L_png/1046.png
# /kaggle/input/iitd-l/L_png/525.png
# /kaggle/input/iitd-l/L_png/120.png
# /kaggle/input/iitd-l/L_png/935.png
# /kaggle/input/iitd-l/L_png/1050.png
# /kaggle/input/iitd-l/L_png/630.png
# /kaggle/input/iitd-l/L_png/271.png
# /kaggle/input/iitd-l/L_png/363.png
# /kaggle/input/iitd-l/L_png/310.png
# /kaggle/input/iitd-l/L_png/323.png
# /kaggle/input/iitd-l/L_png/118.png
# /kaggle/input/iitd-l/L_png/772.png
# /kaggle/input/iitd-l/L_png/670.png
# /kaggle/input/iitd-l/L_png/393.png
# /kaggle/input/iitd-l/L_png/17.png
# /kaggle/input/iitd-l/L_png/53.png
# /kaggle/input/iitd-l/L_png/266.png
# /kaggle/input/iitd-l/L_png/486.png
# /kaggle/input/iitd-l/L_png/657.png
# /kaggle/input/iitd-l/L_png/196.png
# /kaggle/input/iitd-l/L_png/626.png
# /kaggle/input/iitd-l/L_png/877.png
# /kaggle/input/iitd-l/L_png/571.png
# /kaggle/input/iitd-l/L_png/179.png
# /kaggle/input/iitd-l/L_png/178.png
# /kaggle/input/iitd-l/L_png/1186.png
# /kaggle/input/iitd-l/L_png/160.png
# /kaggle/input/iitd-l/L_png/671.png
# /kaggle/input/iitd-l/L_png/140.png
# /kaggle/input/iitd-l/L_png/620.png
# /kaggle/input/iitd-l/L_png/636.png
# /kaggle/input/iitd-l/L_png/1140.png
# /kaggle/input/iitd-l/L_png/736.png
# /kaggle/input/iitd-l/L_png/904.png
# /kaggle/input/iitd-l/L_png/854.png
# /kaggle/input/iitd-l/L_png/1059.png
# /kaggle/input/iitd-l/L_png/52.png
# /kaggle/input/iitd-l/L_png/793.png
# /kaggle/input/iitd-l/L_png/1116.png
# /kaggle/input/iitd-l/L_png/5.png
# /kaggle/input/iitd-l/L_png/139.png
# /kaggle/input/iitd-l/L_png/3.png
# /kaggle/input/iitd-l/L_png/828.png
# /kaggle/input/iitd-l/L_png/172.png
# /kaggle/input/iitd-l/L_png/64.png
# /kaggle/input/iitd-l/L_png/950.png
# /kaggle/input/iitd-l/L_png/841.png
# /kaggle/input/iitd-l/L_png/985.png
# /kaggle/input/iitd-l/L_png/1011.png
# /kaggle/input/iitd-l/L_png/1061.png
# /kaggle/input/iitd-l/L_png/801.png
# /kaggle/input/iitd-l/L_png/406.png
# /kaggle/input/iitd-l/L_png/719.png
# /kaggle/input/iitd-l/L_png/347.png
# /kaggle/input/iitd-l/L_png/955.png
# /kaggle/input/iitd-l/L_png/1094.png
# /kaggle/input/iitd-l/L_png/1159.png
# /kaggle/input/iitd-l/L_png/665.png
# /kaggle/input/iitd-l/L_png/355.png
# /kaggle/input/iitd-l/L_png/16.png
# /kaggle/input/iitd-l/L_png/1028.png
# /kaggle/input/iitd-l/L_png/438.png
# /kaggle/input/iitd-l/L_png/430.png
# /kaggle/input/iitd-l/L_png/800.png
# /kaggle/input/iitd-l/L_png/545.png
# /kaggle/input/iitd-l/L_png/409.png
# /kaggle/input/iitd-l/L_png/967.png
# /kaggle/input/iitd-l/L_png/850.png
# /kaggle/input/iitd-l/L_png/925.png
# /kaggle/input/iitd-l/L_png/725.png
# /kaggle/input/iitd-l/L_png/328.png
# /kaggle/input/iitd-l/L_png/423.png
# /kaggle/input/iitd-l/L_png/643.png
# /kaggle/input/iitd-l/L_png/1127.png
# /kaggle/input/iitd-l/L_png/1099.png
# /kaggle/input/iitd-l/L_png/804.png
# /kaggle/input/iitd-l/L_png/461.png
# /kaggle/input/iitd-l/L_png/375.png
# /kaggle/input/iitd-l/L_png/760.png
# /kaggle/input/iitd-l/L_png/203.png
# /kaggle/input/iitd-l/L_png/8.png
# /kaggle/input/iitd-l/L_png/489.png
# /kaggle/input/iitd-l/L_png/45.png
# /kaggle/input/iitd-l/L_png/382.png
# /kaggle/input/iitd-l/L_png/24.png
# /kaggle/input/iitd-l/L_png/548.png
# /kaggle/input/iitd-l/L_png/444.png
# /kaggle/input/iitd-l/L_png/1066.png
# /kaggle/input/iitd-l/L_png/941.png
# /kaggle/input/iitd-l/L_png/373.png
# /kaggle/input/iitd-l/L_png/922.png
# /kaggle/input/iitd-l/L_png/32.png
# /kaggle/input/iitd-l/L_png/802.png
# /kaggle/input/iitd-l/L_png/88.png
# /kaggle/input/iitd-l/L_png/463.png
# /kaggle/input/iitd-l/L_png/986.png
# /kaggle/input/iitd-l/L_png/649.png
# /kaggle/input/iitd-l/L_png/624.png
# /kaggle/input/iitd-l/L_png/283.png
# /kaggle/input/iitd-l/L_png/274.png
# /kaggle/input/iitd-l/L_png/115.png
# /kaggle/input/iitd-l/L_png/749.png
# /kaggle/input/iitd-l/L_png/249.png
# /kaggle/input/iitd-l/L_png/1040.png
# /kaggle/input/iitd-l/L_png/128.png
# /kaggle/input/iitd-l/L_png/668.png
# /kaggle/input/iitd-l/L_png/158.png
# /kaggle/input/iitd-l/L_png/1086.png
# /kaggle/input/iitd-l/L_png/583.png
# /kaggle/input/iitd-l/L_png/710.png
# /kaggle/input/iitd-l/L_png/807.png
# /kaggle/input/iitd-l/L_png/6.png
# /kaggle/input/iitd-l/L_png/23.png
# /kaggle/input/iitd-l/L_png/87.png
# /kaggle/input/iitd-l/L_png/686.png
# /kaggle/input/iitd-l/L_png/1100.png
# /kaggle/input/iitd-l/L_png/275.png
# /kaggle/input/iitd-l/L_png/787.png
# /kaggle/input/iitd-l/L_png/987.png
# /kaggle/input/iitd-l/L_png/884.png
# /kaggle/input/iitd-l/L_png/51.png
# /kaggle/input/iitd-l/L_png/703.png
# /kaggle/input/iitd-l/L_png/728.png
# /kaggle/input/iitd-l/L_png/591.png
# /kaggle/input/iitd-l/L_png/400.png
# /kaggle/input/iitd-l/L_png/101.png
# /kaggle/input/iitd-l/L_png/606.png
# /kaggle/input/iitd-l/L_png/618.png
# /kaggle/input/iitd-l/L_png/1158.png
# /kaggle/input/iitd-l/L_png/536.png
# /kaggle/input/iitd-l/L_png/717.png
# /kaggle/input/iitd-l/L_png/1133.png
# /kaggle/input/iitd-l/L_png/1184.png
# /kaggle/input/iitd-l/L_png/297.png
# /kaggle/input/iitd-l/L_png/135.png
# /kaggle/input/iitd-l/L_png/794.png
# /kaggle/input/iitd-l/L_png/482.png
# /kaggle/input/iitd-l/L_png/1002.png
# /kaggle/input/iitd-l/L_png/797.png
# /kaggle/input/iitd-l/L_png/740.png
# /kaggle/input/iitd-l/L_png/1069.png
# /kaggle/input/iitd-l/L_png/1016.png
# /kaggle/input/iitd-l/L_png/512.png
# /kaggle/input/iitd-l/L_png/123.png
# /kaggle/input/iitd-l/L_png/91.png
# /kaggle/input/iitd-l/L_png/504.png
# /kaggle/input/iitd-l/L_png/803.png
# /kaggle/input/iitd-l/L_png/862.png
# /kaggle/input/iitd-l/L_png/230.png
# /kaggle/input/iitd-l/L_png/738.png
# /kaggle/input/iitd-l/L_png/826.png
# /kaggle/input/iitd-l/L_png/478.png
# /kaggle/input/iitd-l/L_png/44.png
# /kaggle/input/iitd-l/L_png/399.png
# /kaggle/input/iitd-l/L_png/1151.png
# /kaggle/input/iitd-l/L_png/189.png
# /kaggle/input/iitd-l/L_png/1112.png
# /kaggle/input/iitd-l/L_png/1021.png
# /kaggle/input/iitd-l/L_png/541.png
# /kaggle/input/iitd-l/L_png/1174.png
# /kaggle/input/iitd-l/L_png/601.png
# /kaggle/input/iitd-l/L_png/839.png
# /kaggle/input/iitd-l/L_png/859.png
# /kaggle/input/iitd-l/L_png/1065.png
# /kaggle/input/iitd-l/L_png/442.png
# /kaggle/input/iitd-l/L_png/1053.png
# /kaggle/input/iitd-l/L_png/343.png
# /kaggle/input/iitd-l/L_png/909.png
# /kaggle/input/iitd-l/L_png/454.png
# /kaggle/input/iitd-l/L_png/1052.png
# /kaggle/input/iitd-l/L_png/730.png
# /kaggle/input/iitd-l/L_png/410.png
# /kaggle/input/iitd-l/L_png/68.png
# /kaggle/input/iitd-l/L_png/422.png
# /kaggle/input/iitd-l/L_png/286.png
# /kaggle/input/iitd-l/L_png/964.png
# /kaggle/input/iitd-l/L_png/885.png
# /kaggle/input/iitd-l/L_png/180.png
# /kaggle/input/iitd-l/L_png/858.png
# /kaggle/input/iitd-l/L_png/46.png
# /kaggle/input/iitd-l/L_png/508.png
# /kaggle/input/iitd-l/L_png/499.png
# /kaggle/input/iitd-l/L_png/711.png
# /kaggle/input/iitd-l/L_png/1060.png
# /kaggle/input/iitd-l/L_png/664.png
# /kaggle/input/iitd-l/L_png/516.png
# /kaggle/input/iitd-l/L_png/1095.png
# /kaggle/input/iitd-l/L_png/470.png
# /kaggle/input/iitd-l/L_png/929.png
# /kaggle/input/iitd-l/L_png/57.png
# /kaggle/input/iitd-l/L_png/1101.png
# /kaggle/input/iitd-l/L_png/1080.png
# /kaggle/input/iitd-l/L_png/448.png
# /kaggle/input/iitd-l/L_png/84.png
# /kaggle/input/iitd-l/L_png/475.png
# /kaggle/input/iitd-l/L_png/564.png
# /kaggle/input/iitd-l/L_png/687.png
# /kaggle/input/iitd-l/L_png/1024.png
# /kaggle/input/iitd-l/L_png/1042.png
# /kaggle/input/iitd-l/L_png/15.png
# /kaggle/input/iitd-l/L_png/210.png
# /kaggle/input/iitd-l/L_png/234.png
# /kaggle/input/iitd-l/L_png/358.png
# /kaggle/input/iitd-l/L_png/365.png
# /kaggle/input/iitd-l/L_png/652.png
# /kaggle/input/iitd-l/L_png/946.png
# /kaggle/input/iitd-l/L_png/252.png
# /kaggle/input/iitd-l/L_png/531.png
# /kaggle/input/iitd-l/L_png/507.png
# /kaggle/input/iitd-l/L_png/704.png
# /kaggle/input/iitd-l/L_png/565.png
# /kaggle/input/iitd-l/L_png/679.png
# /kaggle/input/iitd-l/L_png/822.png
# /kaggle/input/iitd-l/L_png/983.png
# /kaggle/input/iitd-l/L_png/523.png
# /kaggle/input/iitd-l/L_png/183.png
# /kaggle/input/iitd-l/L_png/1031.png
# /kaggle/input/iitd-l/L_png/878.png
# /kaggle/input/iitd-l/L_png/678.png
# /kaggle/input/iitd-l/L_png/450.png
# /kaggle/input/iitd-l/L_png/893.png
# /kaggle/input/iitd-l/L_png/30.png
# /kaggle/input/iitd-l/L_png/485.png
# /kaggle/input/iitd-l/L_png/408.png
# /kaggle/input/iitd-l/L_png/631.png
# /kaggle/input/iitd-l/L_png/708.png
# /kaggle/input/iitd-l/L_png/569.png
# /kaggle/input/iitd-l/L_png/919.png
# /kaggle/input/iitd-l/L_png/427.png
# /kaggle/input/iitd-l/L_png/619.png
# /kaggle/input/iitd-l/L_png/622.png
# /kaggle/input/iitd-l/L_png/537.png
# /kaggle/input/iitd-l/L_png/429.png
# /kaggle/input/iitd-l/L_png/1177.png
# /kaggle/input/iitd-l/L_png/783.png
# /kaggle/input/iitd-l/L_png/321.png
# /kaggle/input/iitd-l/L_png/60.png
# /kaggle/input/iitd-l/L_png/235.png
# /kaggle/input/iitd-l/L_png/975.png
# /kaggle/input/iitd-l/L_png/99.png
# /kaggle/input/iitd-l/L_png/155.png
# /kaggle/input/iitd-l/L_png/765.png
# /kaggle/input/iitd-l/L_png/593.png
# /kaggle/input/iitd-l/L_png/676.png
# /kaggle/input/iitd-l/L_png/228.png
# /kaggle/input/iitd-l/L_png/1141.png
# /kaggle/input/iitd-l/L_png/942.png
# /kaggle/input/iitd-l/L_png/27.png
# /kaggle/input/iitd-l/L_png/390.png
# /kaggle/input/iitd-l/L_png/237.png
# /kaggle/input/iitd-l/L_png/451.png
# /kaggle/input/iitd-l/L_png/692.png
# /kaggle/input/iitd-l/L_png/474.png
# /kaggle/input/iitd-l/L_png/292.png
# /kaggle/input/iitd-l/L_png/421.png
# /kaggle/input/iitd-l/L_png/999.png
# /kaggle/input/iitd-l/L_png/201.png
# /kaggle/input/iitd-l/L_png/539.png
# /kaggle/input/iitd-l/L_png/519.png
# /kaggle/input/iitd-l/L_png/845.png
# /kaggle/input/iitd-l/L_png/295.png
# /kaggle/input/iitd-l/L_png/394.png
# /kaggle/input/iitd-l/L_png/273.png
# /kaggle/input/iitd-l/L_png/269.png
# /kaggle/input/iitd-l/L_png/459.png
# /kaggle/input/iitd-l/L_png/413.png
# /kaggle/input/iitd-l/L_png/1058.png
# /kaggle/input/iitd-l/L_png/773.png
# /kaggle/input/iitd-l/L_png/78.png
# /kaggle/input/iitd-l/L_png/212.png
# /kaggle/input/iitd-l/L_png/47.png
# /kaggle/input/iitd-l/L_png/786.png
# /kaggle/input/iitd-l/L_png/207.png
# /kaggle/input/iitd-l/L_png/1110.png
# /kaggle/input/iitd-l/L_png/149.png
# /kaggle/input/iitd-l/L_png/487.png
# /kaggle/input/iitd-l/L_png/812.png
# /kaggle/input/iitd-l/L_png/13.png
# /kaggle/input/iitd-l/L_png/842.png
# /kaggle/input/iitd-l/L_png/974.png
# /kaggle/input/iitd-l/L_png/535.png
# /kaggle/input/iitd-l/L_png/843.png
# /kaggle/input/iitd-l/L_png/260.png
# /kaggle/input/iitd-l/L_png/830.png
# /kaggle/input/iitd-l/L_png/253.png
# /kaggle/input/iitd-l/L_png/206.png
# /kaggle/input/iitd-l/L_png/1034.png
# /kaggle/input/iitd-l/L_png/789.png
# /kaggle/input/iitd-l/L_png/557.png
# /kaggle/input/iitd-l/L_png/980.png
# /kaggle/input/iitd-l/L_png/1175.png
# /kaggle/input/iitd-l/L_png/613.png
# /kaggle/input/iitd-l/L_png/600.png
# /kaggle/input/iitd-l/L_png/874.png
# /kaggle/input/iitd-l/L_png/381.png
# /kaggle/input/iitd-l/L_png/342.png
# /kaggle/input/iitd-l/L_png/1074.png
# /kaggle/input/iitd-l/L_png/346.png
# /kaggle/input/iitd-l/L_png/134.png
# /kaggle/input/iitd-l/L_png/721.png
# /kaggle/input/iitd-l/L_png/898.png
# /kaggle/input/iitd-l/L_png/1124.png
# /kaggle/input/iitd-l/L_png/694.png
# /kaggle/input/iitd-l/L_png/590.png
# /kaggle/input/iitd-l/L_png/1172.png
# /kaggle/input/iitd-l/L_png/566.png
# /kaggle/input/iitd-l/L_png/921.png
# /kaggle/input/iitd-l/L_png/259.png
# /kaggle/input/iitd-l/L_png/25.png
# /kaggle/input/iitd-l/L_png/871.png
# /kaggle/input/iitd-l/L_png/285.png
# /kaggle/input/iitd-l/L_png/341.png
# /kaggle/input/iitd-l/L_png/54.png
# /kaggle/input/iitd-l/L_png/1160.png
# /kaggle/input/iitd-l/L_png/462.png
# /kaggle/input/iitd-l/L_png/851.png
# /kaggle/input/iitd-l/L_png/558.png
# /kaggle/input/iitd-l/L_png/111.png
# /kaggle/input/iitd-l/L_png/611.png
# /kaggle/input/iitd-l/L_png/887.png
# /kaggle/input/iitd-l/L_png/62.png
# /kaggle/input/iitd-l/L_png/205.png
# /kaggle/input/iitd-l/L_png/699.png
# /kaggle/input/iitd-l/L_png/369.png
# /kaggle/input/iitd-l/L_png/750.png
# /kaggle/input/iitd-l/L_png/0.png
# /kaggle/input/iitd-l/L_png/963.png
# /kaggle/input/iitd-l/L_png/141.png
# /kaggle/input/iitd-l/L_png/693.png
# /kaggle/input/iitd-l/L_png/532.png
# /kaggle/input/iitd-l/L_png/309.png
# /kaggle/input/iitd-l/L_png/560.png
# /kaggle/input/iitd-l/L_png/19.png
# /kaggle/input/iitd-l/L_png/110.png
# /kaggle/input/iitd-l/L_png/544.png
# /kaggle/input/iitd-l/L_png/308.png
# /kaggle/input/iitd-l/L_png/26.png
# /kaggle/input/iitd-l/L_png/568.png
# /kaggle/input/iitd-l/L_png/918.png
# /kaggle/input/iitd-l/L_png/388.png
# /kaggle/input/iitd-l/L_png/79.png
# /kaggle/input/iitd-l/L_png/633.png
# /kaggle/input/iitd-l/L_png/824.png
# /kaggle/input/iitd-l/L_png/729.png
# /kaggle/input/iitd-l/L_png/883.png
# /kaggle/input/iitd-l/L_png/257.png
# /kaggle/input/iitd-l/L_png/993.png
# /kaggle/input/iitd-l/L_png/305.png
# /kaggle/input/iitd-l/L_png/477.png
# /kaggle/input/iitd-l/L_png/42.png
# /kaggle/input/iitd-l/L_png/175.png
# /kaggle/input/iitd-l/L_png/961.png
# /kaggle/input/iitd-l/L_png/518.png
# /kaggle/input/iitd-l/L_png/957.png
# /kaggle/input/iitd-l/L_png/226.png
# /kaggle/input/iitd-l/L_png/428.png
# /kaggle/input/iitd-l/L_png/217.png
# /kaggle/input/iitd-l/L_png/867.png
# /kaggle/input/iitd-l/L_png/821.png
# /kaggle/input/iitd-l/L_png/494.png
# /kaggle/input/iitd-l/L_png/837.png
# /kaggle/input/iitd-l/L_png/659.png
# /kaggle/input/iitd-l/L_png/418.png
# /kaggle/input/iitd-l/L_png/452.png
# /kaggle/input/iitd-l/L_png/981.png
# /kaggle/input/iitd-l/L_png/948.png
# /kaggle/input/iitd-l/L_png/306.png
# /kaggle/input/iitd-l/L_png/497.png
# /kaggle/input/iitd-l/L_png/304.png

# %%
import os
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as tt
import torch
import torch.nn as nn
import cv2
from tqdm.notebook import tqdm
import torch.nn.functional as F
from torchvision.utils import save_image
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATA_DIR = "/kaggle/input/iitd-l"

# %%
image_size = 128
batch_size = 8
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

train_ds = ImageFolder(DATA_DIR, transform=tt.Compose([ tt.Resize(image_size),
                                                        tt.CenterCrop(image_size),
                                                        tt.ToTensor(),
                                                        tt.Normalize(*stats)]))

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(train_dl)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %%
discriminator = nn.Sequential(
    # in: 3 x 128 x 128

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 64 x 64

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 32 x 32

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 16 x 16

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 8 x 8

    nn.Conv2d(512, 1, kernel_size=8, stride=1, padding=0, bias=False),
    # out: 1 x 1 x 1

    nn.Flatten(),
    nn.Sigmoid())

# %%
discriminator = to_device(discriminator, device)

# %%
latent_size = 128

# %%
generator = nn.Sequential(
    # in: latent_size x 1 x 1

    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 4 x 4

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 8 x 8

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 16 x 16

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 32 x 32

    nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(32),
    nn.ReLU(True),
    # out: 32 x 64 x 64
    
    nn.ConvTranspose2d(32,3,kernel_size=4,stride=2,padding=1, bias=False),
    nn.Tanh(),
    
    #out: 3x128x128
)

# %%
generator = to_device(generator, device)

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()

# %%
sample_dir = 'generated'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.jpg'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# %%
save_samples(0, fixed_latent)
# Out:
# Saving generated-images-0000.jpg

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in tqdm(train_dl):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.002
epochs = 1 #run for more epochs for better quality

# %%
history = fit(epochs, lr)
# Out:
#   0%|          | 0/149 [00:00<?, ?it/s]
# Epoch [1/1], loss_g: 83.8596, loss_d: 0.0000, real_score: 1.0000, fake_score: 0.0000
# Saving generated-images-0001.jpg

# %%
losses_g, losses_d, real_scores, fake_scores = history

# %%
from IPython.display import Image
Image('./generated/generated-images-0060.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:1035, in Image._repr_mimebundle_(self, include, exclude)
#    1033 if self.embed:
#    1034     mimetype = self._mimetype
# -> 1035     data, metadata = self._data_and_metadata(always_both=True)
#    1036     if metadata:
#    1037         metadata = {mimetype: metadata}
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: './generated/generated-images-0060.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:1067, in Image._repr_png_(self)
#    1065 def _repr_png_(self):
#    1066     if self.embed and self.format == self._FMT_PNG:
# -> 1067         return self._data_and_metadata()
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: './generated/generated-images-0060.jpg'

# %%
os.makedirs("samples1", exist_ok=True)

# %%
for i in range(100):
    fixed_latent = torch.randn(1, latent_size, 1, 1, device=device)
    fake_img = generator(fixed_latent)
    fake_name = "sample{0:0=4d}.jpg".format(i)
    
    save_image(denorm(fake_img), os.path.join("/kaggle/working/samples1", fake_name), nrow=1)

# %%
import shutil
shutil.make_archive("", 'zip', "/kaggle/working/samples1")
# Out:
# '/kaggle/working/.zip'
